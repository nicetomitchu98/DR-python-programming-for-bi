# %% [markdown]
# # Python Programming for Business Intelligence - Final Project
# ## Prepared by Daniil Ruzhinskii

# %% [markdown]
# ## Statement of AI use
#
# AI was used explicitly to prepare the function of imputing the columns with the waterfall priority in the step 2.3.3 and mapping the Rating values in the step 3.3.1
#
# In general, AI was used for consulting purposes throughout the project to map the logical next steps of data pipeline and assitance with the proper handling of financial data related to fixed income.
#
# AI was also used in part of statistical analysis - selecting the hyperparameters and correct evaluation score from confusion matrix to benchmark the model.

# %% [markdown]
# # 0. Introduction

# %% [markdown]
# ##### Goal
# The goal of this project is to examine whether observable bond market features can be used to classify Nordic bonds into credit risk groups using real data extracted from the LSEG Refinitiv API. More specifically, the notebook aims to answer the following question:
#
# Can bond-level market and instrument characteristics such as *yield to maturity, coupon, duration, spread, sector, currency, issuer country, and callable status* help classify bonds by credit rating or bond grade?
#
# To answer this question, the project builds a bond-level dataset for instruments issued in Finland, Sweden, and Norway. The analysis focuses on fixed income instruments and uses data directly extracted from **LSEG** in order to practice working with a real financial API, handling imperfect data, and preparing a dataset for visual and quantitative analysis.
#
# In practical terms, the notebook first identifies available bond instruments through discovery search, then extracts relevant reference and pricing-related fields, and finally combines these with supplementary data when some observations are missing from the primary source. After cleaning and transforming the data, the notebook explores the relationship between bond characteristics and rating-based risk categories using visual analysis and a simple machine learning classification approach.
#
# ##### How to use this notebook
# This notebook is intended as both a project submission and a practical starting point for anyone who wants to begin working with the LSEG Refinitiv API in Python, especially in a fixed income context.
#
# The notebook is structured so that each stage of the workflow is separated clearly:
#
# - importing libraries and field definitions
# - loading discovery search results
# - combining bond files
# - enriching missing fields from supplementary sources
# - cleaning data
# - performing exploratory data analysis
# - classifying bonds into risk groups
#
# ##### Who may benefit/scale
# The notebook may be useful for students who are starting with LSEG data, because although LSEG provides documentation in its developer community and example code in GitHub repositories, it can still be difficult for a beginner to understand how to connect the different parts of the ecosystem smoothly in practice. The examples are either quite narrow or built by the seasoned financial software engineers, and building a working end-to-end workflow for fixed income data on beginner level usually requires additional trial and error. This notebook therefore aims to serve as a more practical and structured example of how to move from raw API extraction to a usable analytical dataset, though on a limited scale.

# %% [markdown]
# # 1. Data Extraction

# %% [markdown]
# ## 1.1. Import libraries and modules
#
# I have prepared the separate .py file with the list of the combined fields which LSEG offers at their extractions. This is much easier to use them as grouped objects to avoid unnecessary long strings in the API calls.

# %%
import json 
import pandas as pd
import lseg.data as ld
import refinitiv.data as rd

# %% [markdown]
# ## 1.2. Load API and check the field groups

# %%
from dotenv import load_dotenv
import os

# Load all variables from .env into the environment
load_dotenv()

lseg_api = os.environ.get("LSEG_API")

if lseg_api:
    print(f"API Key loaded: {lseg_api[:5]}...")
else:
    print("ERROR: Check the correctness of the .env file)")
# Out:
# API Key loaded: f42c2...

# %%
project_fields = [

    # Metadata fields
    "TR.RIC",
    "TR.FiCurrency",

    # Rating supplementary fields
    "TR.IssuerRating",              # Issuer rating
    "TR.IR.RatingSourceDescription", # Rating source,
    "TR.IR.RatingDate",             # Rating date

    "TR.FiFItchsRating",                # Fitch rating
    "TR.FiFItchsRatingDate",
    "TR.FiSPRating",                    # S&P rating
    "TR.FiSPRatingDate",               
    "TR.FiMoodysRating",
    "TR.FiMoodysRatingDate",


    # Duration supplementary fields
    "TR.DurationAnalytics",         # Duration
    "TR.TOTALDURATION",

    "TR.ModifiedDurationAnalytics", # Modified duration
    "TR.MODIFIEDDURATION",

    "TR.FiMaturityCorpMacDuration",
    "TR.MACAULAYDURATION",
    
    # YTM Supplementary fields
    "TR.FiMaturityStandardYield",   # Yield to maturity (YTM)
    "TR.YIELDTOMATURITY",           # Second field of YTM, trying several which will succeed better
    "TR.AVERAGEYIELDTOMATURITY",
    "TR.YieldToMaturityAnalytics",
    
    "TR.FiBondGrade",
    "TR.FiParValue",
    "TR.FiFaceIssuedTotal"
]

# %% [markdown]
# ## 1.3. Perform the Corporate and Gov bond search in Finland

# %% [markdown]
# ### 1.3.1. Discovery search

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x169887920 {name='workspace'}>

# %%
corp_bond_search_fi = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "(DbType eq 'CORP' and IsActive eq true and (RCSCountryGenealogy in ('G:90')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(corp_bond_search_fi.head(-5))
#corp_bond_search_fi.to_csv("corp_bond_search_fi.csv")
# Out:
#                RIC                            DTSubjectName DBSTicker  \
# 0        DEA19JHQ=                OP Asuntoluottopankki Oyj    OPCPRO
# 1        DEA1ZYKN=         Nordea Kiinnitysluottopankki Oyj    NDAFTI
# 2        DEA285A2=                OP Asuntoluottopankki Oyj    OPCPRO
# 3        DEA28SAX=                OP Asuntoluottopankki Oyj    OPCPRO
# 4        DEA2R3NS=         Nordea Kiinnitysluottopankki Oyj    NDAFTI
# ..             ...                                      ...       ...
# 329  XS3330368518=         Nordea Kiinnitysluottopankki Oyj    NDAFTI
# 330           <NA>                      OP-Henkivakuutus Oy    OPOSUL
# 331           <NA>     Taaleri Kiinteistokehitys C-Sarja Ky     TAKOH
# 332           <NA>                      OP-Henkivakuutus Oy    OPOSUL
# 333           <NA>  Taaleri Tuulitehdas II Syottorahasto Ky     TAALT
#
#      CouponRate MaturityDate  IssueDate          ISIN RCSCurrencyLeaf  \
# 0          0.75   2027-06-07 2017-06-07  XS1626141698            Euro
# 1         0.625   2027-03-17 2015-03-17  XS1204140971            Euro
# 2          0.01   2030-11-19 2020-11-19  XS2260183285            Euro
# 3          0.05   2028-04-21 2020-01-21  XS2105779719            Euro
# 4         0.125   2027-06-18 2019-06-18  XS2013525410            Euro
# ..          ...          ...        ...           ...             ...
# 329       2.875   2029-04-03 2026-04-01  XS3330368518            Euro
# 330       6.427          NaT 1999-10-27  FI0003009001            Euro
# 331         0.0          NaT 2015-08-17  FI4000167036            Euro
# 332       6.289          NaT 2001-09-17  FI0002001868            Euro
# 333        <NA>          NaT 2014-11-05  FI4000113089            Euro
#
#     RCSCountryLeaf DbTypeDescription InstrumentTypeDescription  \
# 0          Finland         Corporate      Covered Bond (Other)
# 1          Finland         Corporate      Covered Bond (Other)
# 2          Finland         Corporate      Covered Bond (Other)
# 3          Finland         Corporate      Covered Bond (Other)
# 4          Finland         Corporate      Covered Bond (Other)
# ..             ...               ...                       ...
# 329        Finland         Corporate      Covered Bond (Other)
# 330        Finland         Corporate                      Note
# 331        Finland         Corporate                      Bond
# 332        Finland         Corporate                      Bond
# 333        Finland         Corporate        Structured Product
#
#      RCSBondGradeLeaf  MaturityStandardYield  MaturityCorpMacDuration  \
# 0    Investment Grade               2.809048                 1.081293
# 1    Investment Grade               2.650345                 0.866667
# 2    Investment Grade               3.088424                 4.537793
# 3    Investment Grade               2.949654                 1.960597
# 4    Investment Grade               2.754494                 1.118163
# ..                ...                    ...                      ...
# 329  Investment Grade               2.947038                 2.827664
# 330              <NA>                   <NA>                     <NA>
# 331              <NA>                   <NA>                     <NA>
# 332              <NA>                   <NA>                     <NA>
# 333              <NA>                   <NA>                     <NA>
#
#      MaturityCorpModDuration  IsCallable IndustrySubSectorDescription   Price  \
# 0                   1.066398       False             Mortgage Banking  97.818
# 1                   0.847227       False                      Banking  98.284
# 2                   4.469249       False             Mortgage Banking  87.137
# 3                   1.932298       False             Mortgage Banking  94.551
# 4                    1.10306       False                      Banking  97.137
# ..                       ...         ...                          ...     ...
# 329                  2.78688       False                      Banking  99.798
# 330                     <NA>        True               Life Insurance    <NA>
# 331                     <NA>        True            Financial - Other    <NA>
# 332                     <NA>        True               Life Insurance    <NA>
# 333                     <NA>       False            Financial - Other    <NA>
#
#     PricingTradeDate
# 0         2026-05-01
# 1         2026-05-01
# 2         2026-05-01
# 3         2026-05-01
# 4         2026-05-01
# ..               ...
# 329       2026-05-01
# 330              NaT
# 331              NaT
# 332              NaT
# 333              NaT
#
# [334 rows x 19 columns]

# %%
gov_bond_search_fi = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "(DbType eq 'GOVT' and IsActive eq true and (RCSCountryGenealogy in ('G:90')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(gov_bond_search_fi.head(-5))
#gov_bond_search_fi.to_csv("gov_bond_search_fi.csv")
# Out:
#            RIC                      DTSubjectName DBSTicker  CouponRate  \
# 0   FI0037635=  Finland, Republic of (Government)      FINL        2.75
# 1   FI0046545=  Finland, Republic of (Government)      FINL       2.625
# 2   FI0148630=  Finland, Republic of (Government)      FINL        0.75
# 3   FI0242870=  Finland, Republic of (Government)      FINL       1.375
# 4   FI0278551=  Finland, Republic of (Government)      FINL         0.5
# 5   FI0306758=  Finland, Republic of (Government)      FINL       1.125
# 6   FI0348727=  Finland, Republic of (Government)      FINL         0.5
# 7   FI0369467=  Finland, Republic of (Government)      FINL         0.5
# 8   FI0415153=  Finland, Republic of (Government)      FINL       0.125
# 9   FI0440557=  Finland, Republic of (Government)      FINL        0.25
# 10  FI0441878=  Finland, Republic of (Government)      FINL         0.0
# 11  FI0480488=  Finland, Republic of (Government)      FINL       0.125
# 12  FI0507231=  Finland, Republic of (Government)      FINL       0.125
# 13  FI0511449=  Finland, Republic of (Government)      FINL         0.0
# 14  FI0517677=  Finland, Republic of (Government)      FINL         0.5
# 15  FI0523238=  Finland, Republic of (Government)      FINL         1.5
# 16  FI0527551=  Finland, Republic of (Government)      FINL       1.375
# 17  FI0546528=  Finland, Republic of (Government)      FINL        2.75
# 18  FI0550249=  Finland, Republic of (Government)      FINL         3.0
# 19  FI0557525=  Finland, Republic of (Government)      FINL       2.875
# 20  FI0566294=  Finland, Republic of (Government)      FINL        2.95
# 21  FI0571104=  Finland, Republic of (Government)      FINL         3.0
# 22  FI0577952=  Finland, Republic of (Government)      FINL         2.5
# 23  FI0586284=  Finland, Republic of (Government)      FINL         3.2
# 24  FI0587415=  Finland, Republic of (Government)      FINL         3.0
# 25  FI0590971=  Finland, Republic of (Government)      FIBL         0.0
# 26  FI0591862=  Finland, Republic of (Government)      FINL       2.625
# 27  FI0592183=  Finland, Republic of (Government)      FIBL         0.0
# 28  FI0598396=  Finland, Republic of (Government)      FIBL         0.0
#
#    MaturityDate  IssueDate          ISIN RCSCurrencyLeaf RCSCountryLeaf  \
# 0    2028-07-04 2012-02-07  FI4000037635            Euro        Finland
# 1    2042-07-04 2012-07-03  FI4000046545            Euro        Finland
# 2    2031-04-15 2015-03-10  FI4000148630            Euro        Finland
# 3    2047-04-15 2017-02-15  FI4000242870            Euro        Finland
# 4    2027-09-15 2017-09-06  FI4000278551            Euro        Finland
# 5    2034-04-15 2018-02-13  FI4000306758            Euro        Finland
# 6    2028-09-15 2018-09-04  FI4000348727            Euro        Finland
# 7    2029-09-15 2019-02-12  FI4000369467            Euro        Finland
# 8    2036-04-15 2020-02-11  FI4000415153            Euro        Finland
# 9    2040-09-15 2020-06-17  FI4000440557            Euro        Finland
# 10   2030-09-15 2020-09-02  FI4000441878            Euro        Finland
# 11   2052-04-15 2021-02-09  FI4000480488            Euro        Finland
# 12   2031-09-15 2021-05-26  FI4000507231            Euro        Finland
# 13   2026-09-15 2021-08-31  FI4000511449            Euro        Finland
# 14   2043-04-15 2022-02-02  FI4000517677            Euro        Finland
# 15   2032-09-15 2022-06-01  FI4000523238            Euro        Finland
# 16   2027-04-15 2022-08-30  FI4000527551            Euro        Finland
# 17   2038-04-15 2023-02-02  FI4000546528            Euro        Finland
# 18   2033-09-15 2023-05-04  FI4000550249            Euro        Finland
# 19   2029-04-15 2023-08-30  FI4000557525            Euro        Finland
# 20   2055-04-15 2024-01-24  FI4000566294            Euro        Finland
# 21   2034-09-15 2024-04-30  FI4000571104            Euro        Finland
# 22   2030-04-15 2024-08-27  FI4000577952            Euro        Finland
# 23   2045-04-15 2025-01-29  FI4000586284            Euro        Finland
# 24   2035-09-15 2025-05-07  FI4000587415            Euro        Finland
# 25   2026-05-13 2025-06-05  FI4000590971            Euro        Finland
# 26   2032-04-15 2025-08-28  FI4000591862            Euro        Finland
# 27   2026-08-13 2025-09-11  FI4000592183            Euro        Finland
# 28   2026-11-13 2026-01-09  FI4000598396            Euro        Finland
#
#              DbTypeDescription InstrumentTypeDescription  RCSBondGradeLeaf  \
# 0   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 1   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 2   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 3   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 4   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 5   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 6   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 7   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 8   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 9   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 10  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 11  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 12  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 13  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 14  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 15  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 16  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 17  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 18  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 19  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 20  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 21  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 22  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 23  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 24  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 25  Govt/Treasury/Central Bank                      Bill              <NA>
# 26  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 27  Govt/Treasury/Central Bank                      Bill              <NA>
# 28  Govt/Treasury/Central Bank                      Bill              <NA>
#
#     MaturityStandardYield  MaturityCorpMacDuration  MaturityCorpModDuration  \
# 0                2.649391                 2.084437                 2.057355
# 1                3.697974                12.817836                12.587204
# 2                2.948942                 4.865708                 4.795503
# 3                 3.84727                17.512831                17.185353
# 4                2.676585                 1.356028                 1.338195
# 5                 3.21368                 7.608754                 7.489351
# 6                2.740892                 2.345656                 2.314112
# 7                2.814747                 3.329749                 3.283809
# 8                 3.39851                 9.875749                 9.712082
# 9                3.679606                 14.00356                13.752763
# 10               2.895804                 4.361111                  4.29926
# 11               3.881705                 25.18978                24.714657
# 12               2.990885                 5.340374                 5.262212
# 13               2.227139                 0.361111                 0.358204
# 14               3.786159                16.018408                15.723501
# 15               3.085778                 6.038552                 5.947437
# 16               2.585857                 0.944444                 0.921911
# 17               3.510633                10.250433                10.075096
# 18               3.146722                 6.586598                   6.4853
# 19               2.767163                 2.861523                 2.822725
# 20               3.904184                18.866509                18.508648
# 21               3.249623                 7.369284                 7.252337
# 22               2.860468                  3.79657                 3.743397
# 23               3.782626                14.252226                13.990072
# 24               3.331372                 8.126457                 7.994334
# 25               2.046107                 0.022222                 0.022212
# 26               3.029148                 5.568703                 5.486219
# 27               2.267905                 0.272222                 0.270532
# 28               2.466308                 0.522222                  0.51548
#
#     IsCallable IndustrySubSectorDescription    Price PricingTradeDate
# 0        False                    Sovereign  100.204       2026-05-01
# 1        False                    Sovereign   87.111       2026-05-01
# 2        False                    Sovereign   90.017       2026-05-01
# 3        False                    Sovereign   64.882       2026-05-01
# 4        False                    Sovereign    97.12       2026-05-01
# 5        False                    Sovereign   85.556       2026-05-01
# 6        False                    Sovereign   94.935       2026-05-01
# 7        False                    Sovereign   92.666       2026-05-01
# 8        False                    Sovereign   72.762       2026-05-01
# 9        False                    Sovereign   62.258       2026-05-01
# 10       False                    Sovereign   88.286       2026-05-01
# 11       False                    Sovereign   39.251       2026-05-01
# 12       False                    Sovereign   85.988       2026-05-01
# 13       False                    Sovereign   99.195       2026-05-01
# 14       False                    Sovereign   59.444       2026-05-01
# 15       False                    Sovereign   90.957       2026-05-01
# 16       False                    Sovereign   98.881       2026-05-01
# 17       False                    Sovereign   92.679       2026-05-01
# 18       False                    Sovereign   99.038       2026-05-01
# 19       False                    Sovereign  100.299       2026-05-01
# 20       False                    Sovereign   83.623       2026-05-01
# 21       False                    Sovereign   98.186       2026-05-01
# 22       False                    Sovereign   98.672       2026-05-01
# 23       False                    Sovereign   92.217       2026-05-01
# 24       False                    Sovereign    97.36       2026-05-01
# 25       False                    Sovereign   99.955       2026-05-01
# 26       False                    Sovereign   97.829       2026-05-01
# 27       False                    Sovereign   99.379       2026-05-01
# 28       False                    Sovereign   98.709       2026-05-01

# %% [markdown]
# ### 1.3.2. Supplementary data missing from discovery search

# %%
bond_ric_list_fi = corp_bond_search_fi.iloc[:,0].astype(str).tolist() + gov_bond_search_fi.iloc[:,0].astype(str).tolist()
bond_ric_list_fi
# Out:
# ['DEA19JHQ=',
#  'DEA1ZYKN=',
#  'DEA285A2=',
#  'DEA28SAX=',
#  'DEA2R3NS=',
#  'DEA2RXT8=',
#  'DEA3LTE7=',
#  'DK267356483=',
#  'FI0003030544=',
#  'FI261383829=',
#  'FI271729278=',
#  'FI4000024179=',
#  'FI4000149976=',
#  'FI4000282629=',
#  'FI4000292180=',
#  'FI4000353099=',
#  'FI4000384185=',
#  'FI4000386446=',
#  'FI4000387279=',
#  'FI4000399696=',
#  'FI4000410915=',
#  'FI4000440276=',
#  'FI4000440342=HE',
#  'FI4000440789=HE',
#  'FI4000441753=',
#  'FI4000441803=HE',
#  'FI4000441811=HE',
#  'FI4000441936=HE',
#  'FI4000442108=',
#  'FI4000442264=',
#  'FI4000442314=HE',
#  'FI4000442322=HE',
#  'FI4000456090=',
#  'FI4000456173=HE',
#  'FI4000456199=HE',
#  'FI4000466412=',
#  'FI4000466438=HE',
#  'FI4000466453=HE',
#  'FI4000466602=HE',
#  'FI4000466651=',
#  'FI4000476791=',
#  'FI4000476940=HE',
#  'FI4000476957=HE',
#  'FI4000480041=HE',
#  'FI4000480058=HE',
#  'FI4000480116=',
#  'FI4000480371=',
#  'FI4000480405=HE',
#  'FI4000480439=HE',
#  'FI4000480447=HE',
#  'FI4000480520=HE',
#  'FI4000480538=HE',
#  'FI4000480561=',
#  'FI4000490628=HE',
#  'FI4000490719=',
#  'FI4000490891=HE',
#  'FI4000490917=',
#  'FI4000490933=',
#  'FI4000490941=HE',
#  'FI4000491063=HE',
#  'FI4000491105=',
#  'FI4000496286=',
#  'FI4000496344=',
#  'FI4000496419=',
#  'FI4000496468=',
#  'FI4000496542=',
#  'FI4000496559=HE',
#  'FI4000496567=HE',
#  'FI4000496666=',
#  'FI4000496690=HE',
#  'FI4000496757=',
#  'FI4000496765=LU',
#  'FI4000496799=',
#  'FI4000506886=',
#  'FI4000506944=',
#  'FI4000506985=LU',
#  'FI4000507009=HE',
#  'FI4000507025=',
#  'FI4000507074=',
#  'FI4000507223=LU',
#  'FI4000507298=HE',
#  'FI4000507306=HE',
#  'FI4000507330=',
#  'FI4000507363=',
#  'FI4000507371=',
#  'FI4000507512=LU',
#  'FI4000507579=',
#  'FI4000507587=HE',
#  'FI4000507603=',
#  'FI4000507637=HE',
#  'FI4000507736=',
#  'FI4000507751=HE',
#  'FI4000507769=HE',
#  'FI4000508007=',
#  'FI4000508015=',
#  'FI4000508056=',
#  'FI4000508064=',
#  'FI4000508106=HE',
#  'FI4000508288=HE',
#  'FI4000508296=',
#  'FI4000508304=HE',
#  'FI4000508320=',
#  'FI4000508338=LU',
#  'FI4000508379=LU',
#  'FI4000508403=',
#  'FI4000508411=',
#  'FI4000511480=',
#  'FI4000511621=LU',
#  'FI4000511639=LU',
#  'FI4000511662=',
#  'FI4000511928=',
#  'FI4000512090=HE',
#  'FI4000512108=HE',
#  'FI4000512322=',
#  'FI4000512371=',
#  'FI4000512504=',
#  'FI4000512611=',
#  'FI4000512686=',
#  'FI4000512801=',
#  'FI4000512967=',
#  'FI4000513049=',
#  'FI4000513080=HE',
#  'FI4000513098=HE',
#  'FI4000513106=LU',
#  'FI4000513189=',
#  'FI4000513239=',
#  'FI4000513254=',
#  'FI4000513643=HE',
#  'FI4000513676=',
#  'FI4000513684=',
#  'FI4000513692=',
#  'FI4000513759=HE',
#  'FI4000513890=',
#  'FI4000513957=HE',
#  'FI4000513965=HE',
#  'FI4000513999=',
#  'FI4000514062=',
#  'FI4000514146=',
#  'FI4000514294=',
#  'FI4000517347=',
#  'FI4000517370=TRU',
#  'FI4000517404=HE',
#  'FI4000517412=HE',
#  'FI4000517446=HE',
#  'FI4000517453=HE',
#  'FI4000517636=',
#  'FI4000517792=HE',
#  'FI4000517818=HE',
#  'FI4000517826=',
#  'FI4000517834=',
#  'FI4000518220=',
#  'FI4000518402=HE',
#  'FI4000518410=HE',
#  'FI4000518436=HE',
#  'FI4000518451=',
#  'FI4000518493=',
#  'FI4000518550=LU',
#  'FI4000518683=',
#  'FI4000518790=LU',
#  'FI4000519137=HE',
#  'FI4000519178=',
#  'FI4000519194=LU',
#  'FI4000519244=',
#  'FI4000522370=HE',
#  'FI4000522388=HE',
#  'FI4000522784=HE',
#  'FI4000522800=',
#  'FI4000522875=',
#  'FI4000522974=',
#  'FI4000522990=HE',
#  'FI4000523022=',
#  'FI4000523287=',
#  'FI4000523345.HE',
#  'FI4000523493=',
#  'FI4000523527=',
#  'FI4000523550=',
#  'FI4000523659=HE',
#  'FI4000523857=HE',
#  'FI4000527122=',
#  'FI4000527262=HE',
#  'FI4000527353=LU',
#  'FI4000527361=LU',
#  'FI4000527379=',
#  'FI4000527387=',
#  'FI4000527395=',
#  'FI4000527577.HE',
#  'FI4000530712.HE',
#  'FI4000530746=',
#  'FI4000530787=LU',
#  'FI4000530803=',
#  'FI4000530811=',
#  'FI4000530910=HE',
#  'FI4000530936=HE',
#  'FI4000530951=',
#  'FI4000531066=',
#  'FI4000532338=',
#  'FI4000532593.HE',
#  'FI4000532619.HE',
#  'FI4000532742=',
#  'FI4000532767=',
#  'FI4000532775=',
#  'FI4000532783=HE',
#  'FI4000533088=HE',
#  'FI4000533096.HE',
#  'FI4000536123=BPGL',
#  'FI4000536131=BPGL',
#  'FI4000536206=',
#  'FI4000541263=',
#  'FI4000541297=',
#  'FI4000541461=',
#  'FI4000541628=HE',
#  'FI4000541743=',
#  'FI4000546189=HE',
#  'FI4000546197=BPGL',
#  'FI4000546239=',
#  'FI4000546247=HE',
#  'FI4000546619=MFID',
#  'FI4000546627=',
#  'FI4000546833=',
#  'FI4000546866.HE',
#  'FI4000549035=',
#  'FI4000549241=HE',
#  'FI4000549266=MFID',
#  'FI4000549308=',
#  'FI4000549365=LU',
#  'FI4000549381=LU',
#  'FI4000549415=',
#  'FI4000549423=',
#  'FI4000549605=',
#  'FI4000549647=',
#  'FI4000549654=',
#  'FI4000549662=BPGL',
#  'FI4000549704=',
#  'FI4000549738.HE',
#  'FI4000549779=',
#  'FI4000549795=HE',
#  'FI4000549852=',
#  'FI4000549860=',
#  'FI4000549910=BPGL',
#  'FI4000549951=LU',
#  'FI4000549969=',
#  'FI4000550058=',
#  'FI4000550371=',
#  'FI4000550439=BPGL',
#  'FI4000550454=',
#  'FI4000550462=',
#  'FI4000552484=',
#  'FI4000552559=',
#  'FI4000552856=',
#  'FI4000552898=',
#  'FI4000552922=',
#  'FI4000552971=HE',
#  'FI4000556014=BPGL',
#  'FI4000556154=',
#  'FI4000556261=',
#  'FI4000556311=',
#  'FI4000556329=MFID',
#  'FI4000556410=HE',
#  'FI4000556444=',
#  'FI4000556477=HE',
#  'FI4000556907=HE',
#  'FI4000556998=',
#  'FI4000557111=',
#  'FI4000557145=',
#  'FI4000557152=',
#  'FI4000557244=',
#  'FI4000557376=HE',
#  'FI4000557384=HE',
#  'FI4000557590=BPGL',
#  'FI4000560990=',
#  'FI4000561386=BPGL',
#  'FI4000561725=HE',
#  'FI4000561733=BPGL',
#  'FI4000561931=',
#  'FI4000561949=',
#  'FI4000561956=BPGL',
#  'FI4000562095=',
#  'FI4000562202=',
#  'FI4000562301=',
#  'FI4000562442=HE',
#  'FI4000565635=',
#  'FI4000566187=HE',
#  'FI4000566351=',
#  'FI4000566567=',
#  'FI4000566765=BNPP',
#  'FI4000566773=BNPP',
#  'FI4000566948=',
#  'FI4000566997=',
#  'FI4000567094=',
#  'FI4000567102=',
#  'FI4000567144=',
#  'FI4000570262=',
#  'FI4000570684=',
#  'FI4000570841=',
#  'FI4000570908=',
#  'FI4000570916=HE',
#  'FI4000571237=',
#  'FI4000571245=HE',
#  'FI4000571252=HE',
#  'FI4000571260=',
#  'FI4000571278=',
#  'FI4000571559=',
#  'FI4000571708=',
#  'FI4000578166=',
#  'FI4000578216=',
#  'FI4000578224=',
#  'FI4000581293=',
#  'FI4000581434=',
#  'FI4000581715=',
#  'FI4000586383=',
#  'FI4000587464=',
#  'FI4000590864=',
#  'FI4000591912=',
#  'FI4000592142=',
#  'FI4000592209=',
#  'FI4000592340=',
#  'FI4000597844=',
#  'FI4000597950=',
#  'FI4000597976=',
#  'FI4000598958=',
#  'FI4000599006=',
#  'FI4000602677=',
#  'FIESENS0127=',
#  'SE0016274773=',
#  'XS2058989489=',
#  'XS2081168358=',
#  'XS2532376949=',
#  'XS2589317697=',
#  'XS2802191937=',
#  'XS3330368518=',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  '<NA>',
#  'FI0037635=',
#  'FI0046545=',
#  'FI0148630=',
#  'FI0242870=',
#  'FI0278551=',
#  'FI0306758=',
#  'FI0348727=',
#  'FI0369467=',
#  'FI0415153=',
#  'FI0440557=',
#  'FI0441878=',
#  'FI0480488=',
#  'FI0507231=',
#  'FI0511449=',
#  'FI0517677=',
#  'FI0523238=',
#  'FI0527551=',
#  'FI0546528=',
#  'FI0550249=',
#  'FI0557525=',
#  'FI0566294=',
#  'FI0571104=',
#  'FI0577952=',
#  'FI0586284=',
#  'FI0587415=',
#  'FI0590971=',
#  'FI0591862=',
#  'FI0592183=',
#  'FI0598396=',
#  'FI0598552=',
#  'FI0598776=',
#  'FI0602230=',
#  'FI0602560=',
#  'FI0602891=']

# %%
supplementary_fi = ld.get_data(
    universe=bond_ric_list_fi,
    fields=project_fields,
    parameters = {'SDate': '0CY', 'Curn': 'EUR'}
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_access_layer/_containers.py:62:UserWarning: You have duplicated instruments in your input. Output will contain unique instruments only.
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
display(supplementary_fi.head(-5))
#supplementary_fi.to_csv("supplementary_fi.csv")
# Out:
#      Instrument         RIC Currency Issuer Rating  \
# 0     DEA19JHQ=   DEA19JHQ=      EUR           Aaa
# 1     DEA1ZYKN=   DEA1ZYKN=      EUR      AA (low)
# 2     DEA285A2=   DEA285A2=      EUR           Aaa
# 3     DEA28SAX=   DEA28SAX=      EUR           Aaa
# 4     DEA2R3NS=   DEA2R3NS=      EUR      AA (low)
# ..          ...         ...      ...           ...
# 355  FI0587415=  FI0587415=      EUR            AA
# 356  FI0590971=  FI0590971=      EUR            AA
# 357  FI0591862=  FI0591862=      EUR            AA
# 358  FI0592183=  FI0592183=      EUR            AA
# 359  FI0598396=  FI0598396=      EUR            AA
#
#                              Rating Source Description       Date  \
# 0      Moody's Long-term Mortgage Covered Bonds Rating 2014-11-28
# 1    Dominion Bond Rating Service (DBRS) - Long-ter... 2018-12-07
# 2      Moody's Long-term Mortgage Covered Bonds Rating 2014-11-28
# 3      Moody's Long-term Mortgage Covered Bonds Rating 2014-11-28
# 4    Dominion Bond Rating Service (DBRS) - Long-ter... 2018-12-07
# ..                                                 ...        ...
# 355              Fitch Long-term Issuer Default Rating 2025-07-25
# 356              Fitch Long-term Issuer Default Rating 2025-07-25
# 357              Fitch Long-term Issuer Default Rating 2025-07-25
# 358              Fitch Long-term Issuer Default Rating 2025-07-25
# 359              Fitch Long-term Issuer Default Rating 2025-07-25
#
#     Fitchs Rating Fitchs Rating Date  SP Rating SP Rating Date  ...  \
# 0                                NaT       <NA>            NaT  ...
# 1                                NaT       <NA>            NaT  ...
# 2                                NaT       <NA>            NaT  ...
# 3                                NaT       <NA>            NaT  ...
# 4                                NaT       <NA>            NaT  ...
# ..            ...                ...        ...            ...  ...
# 355            AA         2025-07-25       <NA>            NaT  ...
# 356                              NaT       <NA>            NaT  ...
# 357            AA         2025-08-28       <NA>            NaT  ...
# 358                              NaT       <NA>            NaT  ...
# 359                              NaT       <NA>            NaT  ...
#
#     Modified Duration Mac. Duration  Macaulay Duration Yield To Maturity  \
# 0              1.3803      1.081293               <NA>          2.809048
# 1              1.1639      0.866667               <NA>          2.650345
# 2              4.7371      4.537793               <NA>          3.088424
# 3              2.2345      1.960597               <NA>          2.949654
# 4              1.4181      1.118163               <NA>          2.754494
# ..                ...           ...                ...               ...
# 355            8.2096      8.126457               <NA>          3.331372
# 356            0.3483      0.022222               <NA>          2.046107
# 357            5.6497      5.568703               <NA>          3.029148
# 358            0.5987      0.272222               <NA>          2.267905
# 359              <NA>      0.522222               <NA>          2.466308
#
#      Yield to Maturity  Average Yield to Maturity  Yield to Maturity  \
# 0                 <NA>                                       2.80712
# 1                 <NA>                                      2.793457
# 2                 <NA>                                      3.077096
# 3                 <NA>                                      2.931615
# 4                 <NA>                                      2.726181
# ..                 ...                        ...                ...
# 355               <NA>                                      3.328299
# 356               <NA>                                      2.000176
# 357               <NA>                                      3.010467
# 358               <NA>                                        2.2031
# 359               <NA>                                      2.403081
#
#                        Bond Grade  Par Value  Face Issued Total
# 0    Bond Grade: Investment Grade       1000         1000000000
# 1    Bond Grade: Investment Grade       1000         1000000000
# 2    Bond Grade: Investment Grade       1000         1250000000
# 3    Bond Grade: Investment Grade       1000         1000000000
# 4    Bond Grade: Investment Grade       1000         1000000000
# ..                            ...        ...                ...
# 355  Bond Grade: Investment Grade       1000         9054000000
# 356                                     1000         7297000000
# 357  Bond Grade: Investment Grade       1000         4698000000
# 358                                     1000         5218000000
# 359                                     1000         4276000000
#
# [360 rows x 25 columns]

# %% [markdown]
# ## 1.4. Perform same bond extraction for Sweden

# %%
corp_bond_search_se = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "((DbType eq 'CORP') and IsActive eq true and (RCSCountryGenealogy in ('G:6V')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(corp_bond_search_se.head(-5))
#corp_bond_search_se.to_csv("corp_bond_search_se.csv")
# Out:
#                RIC                                 DTSubjectName DBSTicker  \
# 0        DEA285GL=                               Stadshypotek AB     SHBST
# 1        DEA3KSG2=  AB Sveriges Sakerstallda Obligationer (publ)     SBABS
# 2        DEA3KWUS=                               Stadshypotek AB     SHBST
# 3        DEA3LESB=              Skandinaviska Enskilda Banken AB       SEB
# 4        DEA3LF3E=                               Stadshypotek AB     SHBST
# ..             ...                                           ...       ...
# 490  SE0013884566=                               Hufvudstaden AB      HUFV
# 491  SE0013884582=                                 Ziklo Bank AB     ZKLOK
# 492  SE0013884590=                                 Ziklo Bank AB     ZKLOK
# 493  SE0013884608=                                       Afry AB      AFRY
# 494  SE0013884616=                                       Afry AB      AFRY
#
#      CouponRate MaturityDate  IssueDate          ISIN RCSCurrencyLeaf  \
# 0          0.01   2028-11-24 2020-11-24  XS2262802601            Euro
# 1          0.01   2030-03-14 2021-06-14  XS2353010593            Euro
# 2          0.01   2030-09-30 2021-09-30  XS2391570418            Euro
# 3          3.25   2028-05-04 2023-02-27  XS2592234749            Euro
# 4         3.125   2028-04-04 2023-04-04  XS2607344079            Euro
# ..          ...          ...        ...           ...             ...
# 490       3.888   2028-01-18 2024-01-18  SE0013884566   Swedish Krona
# 491       3.016   2027-01-26 2024-01-26  SE0013884582   Swedish Krona
# 492       3.346   2029-01-26 2024-01-26  SE0013884590   Swedish Krona
# 493        3.97   2029-02-27 2024-02-27  SE0013884608   Swedish Krona
# 494       4.798   2029-02-27 2024-02-27  SE0013884616   Swedish Krona
#
#     RCSCountryLeaf DbTypeDescription               InstrumentTypeDescription  \
# 0           Sweden         Corporate                    Covered Bond (Other)
# 1           Sweden         Corporate  Sakerstallda Obligation (Covered Bond)
# 2           Sweden         Corporate                    Covered Bond (Other)
# 3           Sweden         Corporate  Sakerstallda Obligation (Covered Bond)
# 4           Sweden         Corporate  Sakerstallda Obligation (Covered Bond)
# ..             ...               ...                                     ...
# 490         Sweden         Corporate                                    Bond
# 491         Sweden         Corporate                                    Bond
# 492         Sweden         Corporate                                    Bond
# 493         Sweden         Corporate                                    Bond
# 494         Sweden         Corporate                                    Bond
#
#      RCSBondGradeLeaf  MaturityStandardYield  MaturityCorpMacDuration  \
# 0    Investment Grade               2.947862                 2.552463
# 1    Investment Grade                3.02591                  3.85769
# 2    Investment Grade               3.024998                 4.401684
# 3    Investment Grade               2.907626                 1.965846
# 4    Investment Grade               2.910242                 1.883647
# ..                ...                    ...                      ...
# 490              <NA>               3.113467                 1.665622
# 491              <NA>               2.498345                 0.719377
# 492              <NA>               2.819508                 2.613528
# 493              <NA>               3.404975                 2.650647
# 494              <NA>               4.021995                 2.677398
#
#      MaturityCorpModDuration  IsCallable IndustrySubSectorDescription  \
# 0                   2.515605       False             Mortgage Banking
# 1                   3.800629       False            Financial - Other
# 2                   4.336543       False             Mortgage Banking
# 3                   1.937875       False                      Banking
# 4                   1.856805       False             Mortgage Banking
# ..                       ...         ...                          ...
# 490                 1.640282       False                      Leasing
# 491                 0.227778       False                      Banking
# 492                 0.227778       False                      Banking
# 493                 0.061111       False              Service - Other
# 494                 2.625127       False              Service - Other
#
#        Price PricingTradeDate
# 0     92.867       2026-05-01
# 1     89.173       2026-05-01
# 2     87.737       2026-05-01
# 3    100.655       2026-05-01
# 4    100.391       2026-05-01
# ..       ...              ...
# 490  101.253       2026-05-01
# 491  100.402       2026-05-01
# 492  101.496       2026-05-01
# 493  102.004       2026-05-01
# 494   102.01       2026-05-01
#
# [495 rows x 19 columns]

# %%
gov_bond_search_se = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "(DbType eq 'GOVT' and IsActive eq true and (RCSCountryGenealogy in ('G:6V')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(gov_bond_search_se.head(-5))
#gov_bond_search_se.to_csv("gov_bond_search_se.csv")
# Out:
#            RIC                    DTSubjectName DBSTicker  CouponRate  \
# 0      SE1053=  Sweden, Kingdom of (Government)      SWED         3.5
# 1      SE1056=  Sweden, Kingdom of (Government)      SWED        2.25
# 2      SE1059=  Sweden, Kingdom of (Government)      SWED         1.0
# 3      SE1060=  Sweden, Kingdom of (Government)      SWED        0.75
# 4      SE1061=  Sweden, Kingdom of (Government)      SWED        0.75
# 5      SE1062=  Sweden, Kingdom of (Government)      SWED       0.125
# 6      SE1063=  Sweden, Kingdom of (Government)      SWED         0.5
# 7      SE1064=  Sweden, Kingdom of (Government)      SWED       1.375
# 8      SE1065=  Sweden, Kingdom of (Government)      SWED        1.75
# 9      SE1066=  Sweden, Kingdom of (Government)      SWED        2.25
# 10     SE1068=  Sweden, Kingdom of (Government)      SWED        2.75
# 11  SE2513786=  Sweden, Kingdom of (Government)      SWED         2.5
# 12    SE2605T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 13    SE2606T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 14    SE2607T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 15    SE2608T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 16    SE2609T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 17    SE2612T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 18    SE2703T=  Sweden, Kingdom of (Government)      SEBL         0.0
# 19     SE3103=  Sweden, Kingdom of (Government)     SEINF         3.5
# 20     SE3104=  Sweden, Kingdom of (Government)     SEINF         3.5
# 21     SE3111=  Sweden, Kingdom of (Government)     SEINF       0.125
#
#    MaturityDate  IssueDate          ISIN RCSCurrencyLeaf RCSCountryLeaf  \
# 0    2039-03-30 2009-03-30  SE0002829192   Swedish Krona         Sweden
# 1    2032-06-01 2012-03-20  SE0004517290   Swedish Krona         Sweden
# 2    2026-11-12 2015-05-22  SE0007125927   Swedish Krona         Sweden
# 3    2028-05-12 2017-01-27  SE0009496367   Swedish Krona         Sweden
# 4    2029-11-12 2018-06-01  SE0011281922   Swedish Krona         Sweden
# 5    2031-05-12 2020-03-27  SE0013935319   Swedish Krona         Sweden
# 6    2045-11-24 2020-11-24  SE0015193313   Swedish Krona         Sweden
# 7    2071-06-23 2021-06-23  SE0016102115   Swedish Krona         Sweden
# 8    2033-11-11 2022-05-06  SE0017830730   Swedish Krona         Sweden
# 9    2035-05-11 2024-02-02  SE0021308541   Swedish Krona         Sweden
# 10   2037-02-09 2026-03-18  SE0028000281   Swedish Krona         Sweden
# 11   2036-10-15 2025-06-06  SE0025137862   Swedish Krona         Sweden
# 12   2026-05-20 2026-02-06  SE0027620337   Swedish Krona         Sweden
# 13   2026-06-17 2025-06-23  SE0025198237   Swedish Krona         Sweden
# 14   2026-07-15 2026-04-07  SE0028355024   Swedish Krona         Sweden
# 15   2026-08-19 2026-05-04  SE0028778225   Swedish Krona         Sweden
# 16   2026-09-16 2025-09-05  SE0026142598   Swedish Krona         Sweden
# 17   2026-12-16 2025-12-12  SE0027099375   Swedish Krona         Sweden
# 18   2027-03-17 2026-03-06  SE0028001073   Swedish Krona         Sweden
# 19   2028-12-01 1998-06-26  SE0000479453   Swedish Krona         Sweden
# 20   2028-12-01 1999-04-22  SE0000556599   Swedish Krona         Sweden
# 21   2032-06-01 2015-04-30  SE0007045745   Swedish Krona         Sweden
#
#              DbTypeDescription InstrumentTypeDescription  RCSBondGradeLeaf  \
# 0   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 1   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 2   Govt/Treasury/Central Bank                      Bond              <NA>
# 3   Govt/Treasury/Central Bank                      Bond              <NA>
# 4   Govt/Treasury/Central Bank                      Bond              <NA>
# 5   Govt/Treasury/Central Bank                      Bond              <NA>
# 6   Govt/Treasury/Central Bank                      Bond              <NA>
# 7   Govt/Treasury/Central Bank                      Bond              <NA>
# 8   Govt/Treasury/Central Bank                      Bond              <NA>
# 9   Govt/Treasury/Central Bank                      Bond              <NA>
# 10  Govt/Treasury/Central Bank                      Bond              <NA>
# 11  Govt/Treasury/Central Bank                      Bond              <NA>
# 12  Govt/Treasury/Central Bank                      Bill              <NA>
# 13  Govt/Treasury/Central Bank                      Bill              <NA>
# 14  Govt/Treasury/Central Bank                      Bill              <NA>
# 15  Govt/Treasury/Central Bank                      Bill              <NA>
# 16  Govt/Treasury/Central Bank                      Bill              <NA>
# 17  Govt/Treasury/Central Bank                      Bill              <NA>
# 18  Govt/Treasury/Central Bank                      Bill              <NA>
# 19  Govt/Treasury/Central Bank                      Bond              <NA>
# 20  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 21  Govt/Treasury/Central Bank                      Bond              <NA>
#
#     MaturityStandardYield  MaturityCorpMacDuration  MaturityCorpModDuration  \
# 0                2.980522                10.639007                10.483916
# 1                2.633445                 5.620084                 5.547513
# 2                2.186897                 0.519444                  0.51361
# 3                2.480409                 1.996533                 1.972224
# 4                2.549451                 3.473156                 3.429712
# 5                2.640299                 4.998968                 4.934253
# 6                3.076711                18.300405                18.025213
# 7                3.320976                28.545912                  28.0834
# 8                2.747837                 7.029989                 6.935349
# 9                2.831067                  8.24222                 8.127969
# 10               2.908519                 9.388978                 9.255346
# 11               2.857956                 9.170598                 9.042296
# 12               1.921537                 0.041667                 0.041633
# 13               1.955253                 0.116667                 0.116395
# 14               1.985207                 0.194444                 0.193686
# 15               2.019103                 0.288889                 0.287182
# 16               2.071068                 0.363889                 0.361105
# 17               2.240542                 0.613889                 0.605411
# 18               2.368887                 0.866667                 0.849013
# 19               2.468604                 2.473485                 2.443509
# 20               1.238556                 2.475343                 2.460155
# 21                1.08339                  6.04496                 6.012478
#
#     IsCallable IndustrySubSectorDescription    Price PricingTradeDate
# 0        False                    Sovereign  105.493       2026-05-01
# 1        False                    Sovereign   97.872       2026-05-01
# 2        False                    Sovereign   99.385       2026-05-01
# 3        False                    Sovereign   96.632       2026-05-01
# 4        False                    Sovereign   94.013       2026-05-01
# 5        False                    Sovereign   88.319       2026-05-01
# 6        False                    Sovereign   62.557       2026-05-01
# 7        False                    Sovereign   54.813       2026-05-01
# 8        False                    Sovereign     93.3       2026-05-01
# 9        False                    Sovereign   95.433       2026-05-01
# 10       False                    Sovereign   98.546       2026-05-01
# 11       False                    Sovereign   96.798       2026-05-01
# 12       False                    Sovereign    99.92       2026-05-01
# 13       False                    Sovereign   99.767       2026-05-01
# 14       False                    Sovereign    99.61       2026-05-01
# 15       False                    Sovereign   99.409       2026-05-01
# 16       False                    Sovereign   99.235       2026-05-01
# 17       False                    Sovereign   98.619       2026-05-01
# 18       False                    Sovereign   97.963       2026-05-01
# 19       False                    Sovereign   174.84       2026-05-01
# 20       False                    Sovereign  172.413       2026-05-01
# 21       False                    Sovereign  126.964       2026-05-01

# %%
bond_ric_list_se = corp_bond_search_se.iloc[:,0].astype(str).tolist() + gov_bond_search_se.iloc[:,0].astype(str).tolist()

# %%
supplementary_se = ld.get_data(
    universe=bond_ric_list_se,
    fields=project_fields,
    parameters = {'SDate': '0CY', 'Curn': 'EUR'}
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
display(supplementary_se.head(-5))
#supplementary_se.to_csv("supplementary_se.csv")
# Out:
#     Instrument        RIC Currency Issuer Rating  \
# 0    DEA285GL=  DEA285GL=      EUR           P-1
# 1    DEA3KSG2=  DEA3KSG2=      EUR           Aaa
# 2    DEA3KWUS=  DEA3KWUS=      EUR           P-1
# 3    DEA3LESB=  DEA3LESB=      EUR           AA-
# 4    DEA3LF3E=  DEA3LF3E=      EUR           P-1
# ..         ...        ...      ...           ...
# 517   SE2612T=   SE2612T=      SEK           AAA
# 518   SE2703T=   SE2703T=      SEK           AAA
# 519    SE3103=    SE3103=      SEK           AAA
# 520    SE3104=    SE3104=      SEK           AAA
# 521    SE3111=    SE3111=      SEK           AAA
#
#                              Rating Source Description       Date  \
# 0    Moody's Short-term Issuer Counterparty Risk Ra... 2018-06-26
# 1         Moody's Long-term Other Covered Bonds Rating 2018-10-16
# 2    Moody's Short-term Issuer Counterparty Risk Ra... 2018-06-26
# 3                           Fitch Senior Non-Preferred 2025-05-19
# 4    Moody's Short-term Issuer Counterparty Risk Ra... 2018-06-26
# ..                                                 ...        ...
# 517                        R&I Long-term Issuer Rating 2025-01-27
# 518                        R&I Long-term Issuer Rating 2025-01-27
# 519                        R&I Long-term Issuer Rating 2025-01-27
# 520                        R&I Long-term Issuer Rating 2025-01-27
# 521                        R&I Long-term Issuer Rating 2025-01-27
#
#     Fitchs Rating Fitchs Rating Date  SP Rating SP Rating Date  ...  \
# 0                                NaT       <NA>            NaT  ...
# 1                                NaT       <NA>            NaT  ...
# 2                                NaT       <NA>            NaT  ...
# 3                                NaT       <NA>            NaT  ...
# 4                                NaT       <NA>            NaT  ...
# ..            ...                ...        ...            ...  ...
# 517                              NaT       <NA>            NaT  ...
# 518                              NaT       <NA>            NaT  ...
# 519                              NaT       <NA>            NaT  ...
# 520           AAA         2004-08-06       <NA>            NaT  ...
# 521                              NaT       <NA>            NaT  ...
#
#     Modified Duration Mac. Duration  Macaulay Duration Yield To Maturity  \
# 0              2.8145      2.552463               <NA>          2.947862
# 1              4.0761       3.85769               <NA>           3.02591
# 2               4.608      4.401684               <NA>          3.024998
# 3              2.1907      1.965846               <NA>          2.907626
# 4              2.1129      1.883647               <NA>          2.910242
# ..                ...           ...                ...               ...
# 517          0.087109      0.613889               <NA>          2.240542
# 518              <NA>      0.866667               <NA>          2.368887
# 519              <NA>      2.473485           0.259986          2.468604
# 520              <NA>      2.475343           0.260134          1.238556
# 521              <NA>       6.04496           0.590716           1.08339
#
#      Yield to Maturity  Average Yield to Maturity  Yield to Maturity  \
# 0                                                           2.937672
# 1                                                            3.00585
# 2                                                           2.996095
# 3                                                           2.892549
# 4                                                           2.879879
# ..                 ...                        ...                ...
# 517                                                              1.0
# 518                                                              1.0
# 519                                                        25.342186
# 520                                                        23.137764
# 521                                                         6.189782
#
#                        Bond Grade  Par Value Face Issued Total
# 0    Bond Grade: Investment Grade       1000        1000000000
# 1    Bond Grade: Investment Grade       1000        1000000000
# 2    Bond Grade: Investment Grade       1000        1000000000
# 3    Bond Grade: Investment Grade       1000        1500000000
# 4    Bond Grade: Investment Grade       1000        1000000000
# ..                            ...        ...               ...
# 517                                     5000       35000000000
# 518                                     5000       23100000000
# 519                                     5000        3495210000
# 520  Bond Grade: Investment Grade       5000      118230415000
# 521                                     5000       40800000000
#
# [522 rows x 25 columns]

# %% [markdown]
# ## 1.5. Perform same bond extraction for Norway

# %%
corp_bond_search_no = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "((DbType eq 'CORP') and IsActive eq true and (RCSCountryGenealogy in ('G:3N')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(corp_bond_search_no.head(-5))
#corp_bond_search_no.to_csv("corp_bond_search_no.csv")
# Out:
#             RIC                DTSubjectName DBSTicker  CouponRate  \
# 0     DEA185JS=  Sparebank 1 Boligkreditt AS     SPRBG        0.25
# 1     DEA185TU=          DNB Boligkreditt AS     DNBDB        0.25
# 2     DEA282SD=  Sparebank 1 Boligkreditt AS     SPRBG        0.01
# 3     DEA2RW3D=  Sparebank 1 Boligkreditt AS     SPRBG         1.0
# 4     DEA3K1DE=  Sparebank 1 Boligkreditt AS     SPRBG       0.125
# ..          ...                          ...       ...         ...
# 490  NO1101370=                    Orkla ASA       ORK         4.8
# 491  NO1101371=                    Orkla ASA       ORK      2.4425
# 492  NO1101603=           Bien Sparebank ASA      BIEN        5.13
# 493  NO1101712=          Skagerrak Sparebank    SPARBS        4.75
# 494  NO1101714=                    Entra ASA     ENTRA        4.58
#
#     MaturityDate  IssueDate          ISIN  RCSCurrencyLeaf RCSCountryLeaf  \
# 0     2026-08-30 2016-08-30  XS1482554075             Euro         Norway
# 1     2026-09-07 2016-09-07  XS1485596511             Euro         Norway
# 2     2027-09-22 2020-09-22  XS2234568983             Euro         Norway
# 3     2029-01-30 2019-01-30  XS1943561883             Euro         Norway
# 4     2028-01-20 2022-01-20  XS2434677998             Euro         Norway
# ..           ...        ...           ...              ...            ...
# 490   2028-06-07 2021-06-07  NO0011013708  Norwegian Krone         Norway
# 491   2031-06-04 2021-06-04  NO0011013716  Norwegian Krone         Norway
# 492   2026-08-03 2021-06-03  NO0011016032  Norwegian Krone         Norway
# 493   2026-06-08 2021-06-08  NO0011017121  Norwegian Krone         Norway
# 494   2029-06-07 2021-06-07  NO0011017147  Norwegian Krone         Norway
#
#     DbTypeDescription InstrumentTypeDescription  RCSBondGradeLeaf  \
# 0           Corporate      Covered Bond (Other)  Investment Grade
# 1           Corporate      Covered Bond (Other)  Investment Grade
# 2           Corporate      Covered Bond (Other)  Investment Grade
# 3           Corporate      Covered Bond (Other)  Investment Grade
# 4           Corporate      Covered Bond (Other)  Investment Grade
# ..                ...                       ...               ...
# 490         Corporate                      Bond              <NA>
# 491         Corporate                      Bond              <NA>
# 492         Corporate                      Bond              <NA>
# 493         Corporate                      Bond              <NA>
# 494         Corporate                      Bond              <NA>
#
#      MaturityStandardYield  MaturityCorpMacDuration  MaturityCorpModDuration  \
# 0                 2.415126                 0.319444                  0.31699
# 1                 2.421796                 0.338889                 0.336101
# 2                 2.832195                 1.380453                 1.361268
# 3                 2.953697                 2.705559                 2.666414
# 4                 2.884454                  1.70705                 1.682895
# ..                     ...                      ...                      ...
# 490               4.961666                 1.979362                 0.091667
# 491               5.384815                 4.699457                 4.577777
# 492               4.769368                 0.244444                 0.244444
# 493               4.306814                 0.091667                 0.091667
# 494               5.473689                 2.861124                 0.091667
#
#      IsCallable  IndustrySubSectorDescription   Price PricingTradeDate
# 0         False              Mortgage Banking   99.31       2026-05-01
# 1         False             Financial - Other  99.261       2026-05-01
# 2         False              Mortgage Banking  96.223       2026-05-01
# 3         False              Mortgage Banking  94.927       2026-05-01
# 4         False              Mortgage Banking  95.453       2026-05-01
# ..          ...                           ...     ...              ...
# 490       False  Conglomerate/Diversified Mfg  100.39       2026-05-01
# 491       False  Conglomerate/Diversified Mfg   87.21       2026-05-01
# 492       False                       Banking   100.0       2026-05-01
# 493       False                       Banking  100.04       2026-05-01
# 494       False               Service - Other   98.49       2026-05-01
#
# [495 rows x 19 columns]

# %%
gov_bond_search_no = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "(DbType eq 'GOVT' and IsActive eq true and (RCSCountryGenealogy in ('G:3N')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(gov_bond_search_no.head(-5))
#gov_bond_search_no.to_csv("gov_bond_search_no.csv")
# Out:
#               RIC                    DTSubjectName DBSTicker  CouponRate  \
# 0   NO0010786288=  Norway, Kingdom Of (Government)    NORWAY        1.75
# 1   NO0010821598=  Norway, Kingdom Of (Government)    NORWAY         2.0
# 2   NO0010844079=  Norway, Kingdom Of (Government)    NORWAY        1.75
# 3   NO0010875230=  Norway, Kingdom Of (Government)    NORWAY       1.375
# 4   NO0010930522=  Norway, Kingdom Of (Government)    NORWAY        1.25
# 5   NO0012440397=  Norway, Kingdom Of (Government)    NORWAY       2.125
# 6   NO0012712506=  Norway, Kingdom Of (Government)    NORWAY         3.5
# 7   NO0012837642=  Norway, Kingdom Of (Government)    NORWAY         3.0
# 8   NO0013148338=  Norway, Kingdom Of (Government)    NORWAY       3.625
# 9   NO0013238246=  Norway, Kingdom Of (Government)    NORWAY       3.625
# 10  NO0013475558=  Norway, Kingdom Of (Government)    NORWAY        3.75
# 11  NO0013583377=  Norway, Kingdom Of (Government)    NORWAY         0.0
# 12  NO0013660423=  Norway, Kingdom Of (Government)    NORWAY         0.0
# 13  NO0013708610=  Norway, Kingdom Of (Government)    NORWAY         0.0
# 14  NO0013713123=  Norway, Kingdom Of (Government)    NORWAY       4.125
# 15  NO0013737973=  Norway, Kingdom Of (Government)    NORWAY         0.0
# 16     NO1079129=       Faroe Islands (Government)      <NA>         2.7
# 17           <NA>                      Norges Bank     NRGBK         0.0
# 18           <NA>                      Norges Bank     NRGBK         0.0
# 19           <NA>                      Norges Bank     NRGBK         0.0
# 20           <NA>                      Norges Bank     NRGBK         0.0
# 21           <NA>                      Norges Bank     NRGBK         0.0
# 22           <NA>                      Norges Bank     NRGBK         0.0
# 23           <NA>                      Norges Bank     NRGBK         0.0
# 24           <NA>                      Norges Bank     NRGBK         0.0
# 25           <NA>                      Norges Bank     NRGBK         0.0
# 26           <NA>                      Norges Bank     NRGBK         0.0
# 27           <NA>                      Norges Bank     NRGBK         0.0
# 28           <NA>                      Norges Bank     NRGBK         0.0
# 29           <NA>                      Norges Bank     NRGBK         0.0
# 30           <NA>                      Norges Bank     NRGBK         0.0
# 31           <NA>                      Norges Bank     NRGBK         0.0
# 32           <NA>                      Norges Bank     NRGBK         0.0
# 33           <NA>                      Norges Bank     NRGBK         0.0
# 34           <NA>                      Norges Bank     NRGBK         0.0
# 35           <NA>                      Norges Bank     NRGBK         0.0
# 36           <NA>                      Norges Bank     NRGBK         0.0
# 37           <NA>                      Norges Bank     NRGBK         0.0
# 38           <NA>                      Norges Bank     NRGBK         0.0
# 39           <NA>                      Norges Bank     NRGBK         0.0
# 40           <NA>                      Norges Bank     NRGBK         0.0
#
#    MaturityDate  IssueDate          ISIN  RCSCurrencyLeaf RCSCountryLeaf  \
# 0    2027-02-17 2017-02-17  NO0010786288  Norwegian Krone         Norway
# 1    2028-04-26 2018-04-26  NO0010821598  Norwegian Krone         Norway
# 2    2029-09-06 2019-03-06  NO0010844079  Norwegian Krone         Norway
# 3    2030-08-19 2020-02-19  NO0010875230  Norwegian Krone         Norway
# 4    2031-09-17 2021-02-17  NO0010930522  Norwegian Krone         Norway
# 5    2032-05-18 2022-02-16  NO0012440397  Norwegian Krone         Norway
# 6    2042-10-06 2022-10-06  NO0012712506  Norwegian Krone         Norway
# 7    2033-08-15 2023-02-15  NO0012837642  Norwegian Krone         Norway
# 8    2034-04-13 2024-02-13  NO0013148338  Norwegian Krone         Norway
# 9    2039-05-31 2024-05-31  NO0013238246  Norwegian Krone         Norway
# 10   2035-06-12 2025-02-12  NO0013475558  Norwegian Krone         Norway
# 11   2026-06-17 2025-06-18  NO0013583377  Norwegian Krone         Norway
# 12   2026-09-16 2025-09-17  NO0013660423  Norwegian Krone         Norway
# 13   2026-12-16 2025-12-17  NO0013708610  Norwegian Krone         Norway
# 14   2036-06-03 2026-02-03  NO0013713123  Norwegian Krone         Norway
# 15   2027-03-17 2026-03-18  NO0013737973  Norwegian Krone         Norway
# 16   2032-05-03 2017-05-03  NO0010791296  Norwegian Krone         Norway
# 17   2026-06-11 2026-05-15  NO0013741009  Norwegian Krone         Norway
# 18   2026-06-18 2026-05-21  NO0013741017  Norwegian Krone         Norway
# 19   2026-06-25 2026-05-28  NO0013741025  Norwegian Krone         Norway
# 20   2026-07-02 2026-06-04  NO0013741041  Norwegian Krone         Norway
# 21   2026-07-09 2026-06-11  NO0013741058  Norwegian Krone         Norway
# 22   2026-07-23 2026-06-25  NO0013741074  Norwegian Krone         Norway
# 23   2026-08-13 2026-07-16  NO0013741116  Norwegian Krone         Norway
# 24   2026-08-20 2026-07-23  NO0013741140  Norwegian Krone         Norway
# 25   2026-08-27 2026-07-30  NO0013741165  Norwegian Krone         Norway
# 26   2026-09-17 2026-08-20  NO0013741199  Norwegian Krone         Norway
# 27   2026-09-24 2026-08-27  NO0013741215  Norwegian Krone         Norway
# 28   2026-09-24 2026-07-02  NO0013741082  Norwegian Krone         Norway
# 29   2026-10-01 2026-09-03  NO0013741223  Norwegian Krone         Norway
# 30   2026-10-08 2026-09-10  NO0013741231  Norwegian Krone         Norway
# 31   2026-10-15 2026-09-17  NO0013741249  Norwegian Krone         Norway
# 32   2026-10-22 2026-09-24  NO0013741264  Norwegian Krone         Norway
# 33   2026-10-22 2026-07-30  NO0013741157  Norwegian Krone         Norway
# 34   2026-10-29 2026-10-01  NO0013741272  Norwegian Krone         Norway
# 35   2026-11-05 2026-10-08  NO0013741280  Norwegian Krone         Norway
# 36   2026-11-12 2026-10-15  NO0013741298  Norwegian Krone         Norway
# 37   2026-11-19 2026-10-22  NO0013741314  Norwegian Krone         Norway
# 38   2026-11-19 2026-08-27  NO0013741207  Norwegian Krone         Norway
# 39   2026-12-03 2026-11-05  NO0013741330  Norwegian Krone         Norway
# 40   2026-12-10 2026-11-12  NO0013741348  Norwegian Krone         Norway
#
#              DbTypeDescription InstrumentTypeDescription  RCSBondGradeLeaf  \
# 0   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 1   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 2   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 3   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 4   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 5   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 6   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 7   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 8   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 9   Govt/Treasury/Central Bank                      Bond  Investment Grade
# 10  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 11  Govt/Treasury/Central Bank                      Bill              <NA>
# 12  Govt/Treasury/Central Bank                      Bill              <NA>
# 13  Govt/Treasury/Central Bank                      Bill              <NA>
# 14  Govt/Treasury/Central Bank                      Bond  Investment Grade
# 15  Govt/Treasury/Central Bank                      Bill              <NA>
# 16  Govt/Treasury/Central Bank                      Bond              <NA>
# 17  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 18  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 19  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 20  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 21  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 22  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 23  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 24  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 25  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 26  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 27  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 28  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 29  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 30  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 31  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 32  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 33  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 34  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 35  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 36  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 37  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 38  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 39  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
# 40  Govt/Treasury/Central Bank    Certificate of Deposit              <NA>
#
#     MaturityStandardYield  MaturityCorpMacDuration  MaturityCorpModDuration  \
# 0                4.475805                 0.783333                 0.756613
# 1                4.614443                   1.9549                 1.911299
# 2                4.594938                 3.227579                 3.155888
# 3                 4.56699                 4.142544                 4.051071
# 4                 4.47125                 5.163288                 5.051588
# 5                4.445564                 5.574683                 5.454754
# 6                4.462802                12.232147                11.968008
# 7                4.396221                 6.462024                 6.324499
# 8                4.390702                 6.996399                 6.847683
# 9                4.466782                 10.14362                 9.924391
# 10               4.403238                 7.576187                 7.414702
# 11               4.097728                 0.116667                 0.116116
# 12                4.33247                 0.363889                 0.358267
# 13               4.395767                 0.613889                 0.597823
# 14               4.432392                 8.331171                 8.152455
# 15               4.533765                 0.866667                 0.834028
# 16               4.705905                 5.588317                  5.46129
# 17                   <NA>                     <NA>                     <NA>
# 18                   <NA>                     <NA>                     <NA>
# 19                   <NA>                     <NA>                     <NA>
# 20                   <NA>                     <NA>                     <NA>
# 21                   <NA>                     <NA>                     <NA>
# 22                   <NA>                     <NA>                     <NA>
# 23                   <NA>                     <NA>                     <NA>
# 24                   <NA>                     <NA>                     <NA>
# 25                   <NA>                     <NA>                     <NA>
# 26                   <NA>                     <NA>                     <NA>
# 27                   <NA>                     <NA>                     <NA>
# 28                   <NA>                     <NA>                     <NA>
# 29                   <NA>                     <NA>                     <NA>
# 30                   <NA>                     <NA>                     <NA>
# 31                   <NA>                     <NA>                     <NA>
# 32                   <NA>                     <NA>                     <NA>
# 33                   <NA>                     <NA>                     <NA>
# 34                   <NA>                     <NA>                     <NA>
# 35                   <NA>                     <NA>                     <NA>
# 36                   <NA>                     <NA>                     <NA>
# 37                   <NA>                     <NA>                     <NA>
# 38                   <NA>                     <NA>                     <NA>
# 39                   <NA>                     <NA>                     <NA>
# 40                   <NA>                     <NA>                     <NA>
#
#     IsCallable IndustrySubSectorDescription   Price PricingTradeDate
# 0        False                    Sovereign   97.91       2026-05-01
# 1        False                    Sovereign   95.17       2026-05-01
# 2        False                    Sovereign   91.38       2026-05-01
# 3        False                    Sovereign  87.813       2026-05-01
# 4        False                    Sovereign  84.924       2026-05-01
# 5        False                    Sovereign  87.944       2026-05-01
# 6        False                    Sovereign   88.95       2026-05-01
# 7        False                    Sovereign  91.454       2026-05-01
# 8        False                    Sovereign  94.958       2026-05-01
# 9        False                    Sovereign   91.79       2026-05-01
# 10       False                    Sovereign  95.184       2026-05-01
# 11       False                    Sovereign  99.528       2026-05-01
# 12       False                    Sovereign  98.455       2026-05-01
# 13       False                    Sovereign  97.383       2026-05-01
# 14       False                    Sovereign  97.573       2026-05-01
# 15       False                    Sovereign  96.234       2026-05-01
# 16       False                    Sovereign   89.73       2026-05-01
# 17       False                       Agency    <NA>              NaT
# 18       False                       Agency    <NA>              NaT
# 19       False                       Agency    <NA>              NaT
# 20       False                       Agency    <NA>              NaT
# 21       False                       Agency    <NA>              NaT
# 22       False                       Agency    <NA>              NaT
# 23       False                       Agency    <NA>              NaT
# 24       False                       Agency    <NA>              NaT
# 25       False                       Agency    <NA>              NaT
# 26       False                       Agency    <NA>              NaT
# 27       False                       Agency    <NA>              NaT
# 28       False                       Agency    <NA>              NaT
# 29       False                       Agency    <NA>              NaT
# 30       False                       Agency    <NA>              NaT
# 31       False                       Agency    <NA>              NaT
# 32       False                       Agency    <NA>              NaT
# 33       False                       Agency    <NA>              NaT
# 34       False                       Agency    <NA>              NaT
# 35       False                       Agency    <NA>              NaT
# 36       False                       Agency    <NA>              NaT
# 37       False                       Agency    <NA>              NaT
# 38       False                       Agency    <NA>              NaT
# 39       False                       Agency    <NA>              NaT
# 40       False                       Agency    <NA>              NaT

# %%
bond_ric_list_no = corp_bond_search_no.iloc[:,0].astype(str).tolist() + gov_bond_search_no.iloc[:,0].dropna().astype(str).tolist()

# %%
supplementary_no = ld.get_data(
    universe=bond_ric_list_no,
    fields=project_fields,
    parameters = {'SDate': '0CY', 'Curn': 'EUR'}
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
display(supplementary_no.head(-5))
#supplementary_no.to_csv("supplementary_no.csv")
# Out:
#         Instrument            RIC Currency Issuer Rating  \
# 0        DEA185JS=      DEA185JS=      EUR       Aa3(cr)
# 1        DEA185TU=      DEA185TU=      EUR            WR
# 2        DEA282SD=      DEA282SD=      EUR       Aa3(cr)
# 3        DEA2RW3D=      DEA2RW3D=      EUR       Aa3(cr)
# 4        DEA3K1DE=      DEA3K1DE=      EUR       Aa3(cr)
# ..             ...            ...      ...           ...
# 510  NO0012837642=  NO0012837642=      NOK           AAA
# 511  NO0013148338=  NO0013148338=      NOK           AAA
# 512  NO0013238246=  NO0013238246=      NOK           AAA
# 513  NO0013475558=  NO0013475558=      NOK           AAA
# 514  NO0013583377=  NO0013583377=      NOK           AAA
#
#                           Rating Source Description       Date Fitchs Rating  \
# 0    Moody's Long-term Counterparty Risk Assessment 2023-11-03            WD
# 1      Moody's Long-term Other Covered Bonds Rating 2018-12-20
# 2    Moody's Long-term Counterparty Risk Assessment 2023-11-03
# 3    Moody's Long-term Counterparty Risk Assessment 2023-11-03
# 4    Moody's Long-term Counterparty Risk Assessment 2023-11-03
# ..                                              ...        ...           ...
# 510                     JCR Long-term Issuer Rating 2025-09-19
# 511                     JCR Long-term Issuer Rating 2025-09-19
# 512                     JCR Long-term Issuer Rating 2025-09-19
# 513                     JCR Long-term Issuer Rating 2025-09-19
# 514                     JCR Long-term Issuer Rating 2025-09-19
#
#     Fitchs Rating Date  SP Rating SP Rating Date  ... Modified Duration  \
# 0           2017-10-25       <NA>            NaT  ...            0.6406
# 1                  NaT       <NA>            NaT  ...            0.6618
# 2                  NaT       <NA>            NaT  ...             1.674
# 3                  NaT       <NA>            NaT  ...            2.9337
# 4                  NaT       <NA>            NaT  ...            1.9911
# ..                 ...        ...            ...  ...               ...
# 510                NaT       <NA>            NaT  ...           0.55489
# 511                NaT       <NA>            NaT  ...          0.576028
# 512                NaT       <NA>            NaT  ...          0.855688
# 513                NaT       <NA>            NaT  ...           0.64564
# 514                NaT       <NA>            NaT  ...          0.036364
#
#     Mac. Duration  Macaulay Duration Yield To Maturity  Yield to Maturity  \
# 0        0.319444               <NA>          2.415126               <NA>
# 1        0.338889               <NA>          2.421796               <NA>
# 2        1.380453               <NA>          2.832195               <NA>
# 3        2.705559               <NA>          2.953697               <NA>
# 4         1.70705               <NA>          2.884454               <NA>
# ..            ...                ...               ...                ...
# 510      6.462024               <NA>          4.396221               <NA>
# 511      6.996399               <NA>          4.390702               <NA>
# 512      10.14362               <NA>          4.466782               <NA>
# 513      7.576187               <NA>          4.403238               <NA>
# 514      0.116667               <NA>          4.097728               <NA>
#
#      Average Yield to Maturity  Yield to Maturity  \
# 0                                        2.416706
# 1                                        2.375904
# 2                                         2.83992
# 3                                        2.939927
# 4                                        2.869344
# ..                         ...                ...
# 510                                      4.372773
# 511                                      4.370182
# 512                                      4.446731
# 513                                      4.381445
# 514                                      4.048912
#
#                        Bond Grade  Par Value  Face Issued Total
# 0    Bond Grade: Investment Grade       1000         1000000000
# 1    Bond Grade: Investment Grade       1000         1500000000
# 2    Bond Grade: Investment Grade       1000         1000000000
# 3    Bond Grade: Investment Grade       1000         1250000000
# 4    Bond Grade: Investment Grade       1000         1250000000
# ..                            ...        ...                ...
# 510  Bond Grade: Investment Grade       1000        59098000000
# 511  Bond Grade: Investment Grade       1000        52430000000
# 512  Bond Grade: Investment Grade       1000        32481000000
# 513  Bond Grade: Investment Grade       1000        63505000000
# 514                                     1000        18000000000
#
# [515 rows x 25 columns]

# %% [markdown]
# ## 1.6. Perform same bond extraction for Denmark

# %%
corp_bond_search_dk = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "((DbType eq 'CORP') and IsActive eq true and (RCSCountryGenealogy in ('G:19')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(corp_bond_search_dk.head(-5))
#corp_bond_search_dk.to_csv("corp_bond_search_dk.csv")
# Out:
#                  RIC                         DTSubjectName DBSTicker  \
# 0    0#DK0030237029=                          Sjf Bank A/S       SJF
# 1    0#DK0030239314=                          Sjf Bank A/S       SJF
# 2    0#DK0030248067=                          Sjf Bank A/S       SJF
# 3    0#DK0030256169=                    Fjordbank Mors A/S     FJORB
# 4      DK0002000421=  Nordea Kredit Realkreditaktieselskab    NDARFI
# ..               ...                                   ...       ...
# 490    DK0006322953=                        DLR Kredit A/S     DLRKR
# 491    DK0006323092=                        DLR Kredit A/S     DLRKR
# 492    DK0006323175=                        DLR Kredit A/S     DLRKR
# 493    DK0006323258=                        DLR Kredit A/S     DLRKR
# 494    DK0006323928=                        DLR Kredit A/S     DLRKR
#
#      CouponRate MaturityDate  IssueDate          ISIN RCSCurrencyLeaf  \
# 0          1.83   2013-03-12 2010-03-12  DK0030237029    Danish Krone
# 1        1.8825   2013-04-23 2010-04-23  DK0030239314    Danish Krone
# 2         1.675   2013-06-28 2010-06-28  DK0030248067    Danish Krone
# 3         1.655   2013-07-22 2010-07-22  DK0030256169    Danish Krone
# 4           6.0   2026-07-01 1993-10-18  DK0002000421    Danish Krone
# ..          ...          ...        ...           ...             ...
# 490         5.0   2038-04-01 2005-01-17  DK0006322953    Danish Krone
# 491         4.0   2036-04-01 2005-04-29  DK0006323092    Danish Krone
# 492         4.0   2028-01-01 2005-05-12  DK0006323175    Danish Krone
# 493         4.0   2036-04-01 2005-06-06  DK0006323258    Danish Krone
# 494         5.0   2028-04-01 2006-04-21  DK0006323928    Danish Krone
#
#     RCSCountryLeaf DbTypeDescription  \
# 0          Denmark         Corporate
# 1          Denmark         Corporate
# 2          Denmark         Corporate
# 3          Denmark         Corporate
# 4          Denmark         Corporate
# ..             ...               ...
# 490        Denmark         Corporate
# 491        Denmark         Corporate
# 492        Denmark         Corporate
# 493        Denmark         Corporate
# 494        Denmark         Corporate
#
#                              InstrumentTypeDescription  MaturityStandardYield  \
# 0                                                 Bond                   <NA>
# 1                                                 Bond                   <NA>
# 2                                                 Bond                   <NA>
# 3                                                 Bond                   <NA>
# 4    Realkreditobligation (Covered bond (Denmark pr...                2.54321
# ..                                                 ...                    ...
# 490                               Realkreditobligation               4.470782
# 491                               Realkreditobligation               3.586047
# 492                               Realkreditobligation               4.525377
# 493                               Realkreditobligation               3.775167
# 494                               Realkreditobligation               4.012077
#
#      MaturityCorpMacDuration  MaturityCorpModDuration  IsCallable  \
# 0                       <NA>                     <NA>       False
# 1                       <NA>                     <NA>       False
# 2                       <NA>                     <NA>        True
# 3                       <NA>                     <NA>        True
# 4                   0.155556                 0.154932        True
# ..                       ...                      ...         ...
# 490                 5.499684                 5.378753        True
# 491                 4.733801                 4.650033        True
# 492                 0.894294                 0.874374        True
# 493                 4.718295                  4.63046        True
# 494                 1.017445                 0.997317        True
#
#     IndustrySubSectorDescription    Price PricingTradeDate
# 0                        Banking     <NA>              NaT
# 1                        Banking     <NA>              NaT
# 2                        Banking     <NA>              NaT
# 3                        Banking     <NA>              NaT
# 4               Mortgage Banking    100.5       2026-05-01
# ..                           ...      ...              ...
# 490            Financial - Other    102.4       2026-05-01
# 491            Financial - Other  101.675       2026-05-01
# 492            Financial - Other   99.475       2026-05-01
# 493            Financial - Other  100.775       2026-05-01
# 494            Financial - Other    100.9       2026-05-01
#
# [495 rows x 18 columns]

# %%
gov_bond_search_dk = ld.discovery.search(
	view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
	top = 500,
	filter = "(DbType eq 'GOVT' and IsActive eq true and (RCSCountryGenealogy in ('G:19')))",
	select = "RIC,DTSubjectName,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSBondGradeLeaf,MaturityStandardYield,MaturityCorpMacDuration,MaturityCorpModDuration,IsCallable,IndustrySubSectorDescription,Price,PricingTradeDate",
	order_by = "RIC"
)

# %%
display(gov_bond_search_dk.head(-5))
#gov_bond_search_dk.to_csv("gov_bond_search_dk.csv")
# Out:
#               RIC                     DTSubjectName DBSTicker  CouponRate  \
# 0   DK0009820243=  Denmark, Kingdom of (Government)      DKBL         0.0
# 1   DK0009820409=  Denmark, Kingdom of (Government)      DKBL         0.0
# 2   DK0009922320=  Denmark, Kingdom of (Government)      DENK         4.5
# 3   DK0009923567=  Denmark, Kingdom of (Government)      DENK         0.5
# 4   DK0009923724=  Denmark, Kingdom of (Government)      DENK         0.1
# 5   DK0009923807=  Denmark, Kingdom of (Government)      DENK         0.5
# 6   DK0009924029=  Denmark, Kingdom of (Government)      DENK        0.25
# 7   DK0009924102=  Denmark, Kingdom of (Government)      DENK         0.0
# 8   DK0009924375=  Denmark, Kingdom of (Government)      DENK         0.0
# 9   DK0009924458=  Denmark, Kingdom of (Government)      DENK         0.1
# 10  DK0009924532=  Denmark, Kingdom of (Government)      DENK        2.25
# 11  DK0009924615=  Denmark, Kingdom of (Government)      DENK        2.25
# 12  DK0009924888=  Denmark, Kingdom of (Government)      DENK        2.25
# 13  DK0009924961=  Denmark, Kingdom of (Government)      DENK        2.25
# 14  DK0009925182=  Denmark, Kingdom of (Government)      DENK        2.25
#
#    MaturityDate  IssueDate          ISIN RCSCurrencyLeaf RCSCountryLeaf  \
# 0    2026-06-02 2025-12-02  DK0009820243    Danish Krone        Denmark
# 1    2026-09-02 2026-03-03  DK0009820409    Danish Krone        Denmark
# 2    2039-11-15 2008-11-11  DK0009922320    Danish Krone        Denmark
# 3    2027-11-15 2017-01-27  DK0009923567    Danish Krone        Denmark
# 4    2030-11-15 2018-02-09  DK0009923724    Danish Krone        Denmark
# 5    2029-11-15 2019-01-25  DK0009923807    Danish Krone        Denmark
# 6    2052-11-15 2020-04-03  DK0009924029    Danish Krone        Denmark
# 7    2031-11-15 2021-01-22  DK0009924102    Danish Krone        Denmark
# 8    2031-11-15 2022-01-21  DK0009924375    Danish Krone        Denmark
# 9    2034-11-15 2022-09-16  DK0009924458    Danish Krone        Denmark
# 10   2033-11-15 2023-02-10  DK0009924532    Danish Krone        Denmark
# 11   2033-11-15 2023-10-03  DK0009924615    Danish Krone        Denmark
# 12   2026-11-15 2024-02-09  DK0009924888    Danish Krone        Denmark
# 13   2035-11-15 2025-02-07  DK0009924961    Danish Krone        Denmark
# 14   2035-11-15 2025-09-30  DK0009925182    Danish Krone        Denmark
#
#              DbTypeDescription InstrumentTypeDescription  RCSBondGradeLeaf  \
# 0   Govt/Treasury/Central Bank                      Bill              <NA>
# 1   Govt/Treasury/Central Bank                      Bill              <NA>
# 2   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 3   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 4   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 5   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 6   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 7   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 8   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 9   Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 10  Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 11  Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 12  Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 13  Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
# 14  Govt/Treasury/Central Bank    Danish Government Bond  Investment Grade
#
#     MaturityStandardYield  MaturityCorpMacDuration  MaturityCorpModDuration  \
# 0                1.830692                    0.075                 0.074894
# 1                1.969469                    0.325                 0.322894
# 2                3.055939                10.483703                 10.32704
# 3                 2.33437                 1.522712                 1.505202
# 4                0.385699                 4.517712                 4.509018
# 5                2.483357                 3.496649                 3.453979
# 6                3.232305                25.108342                24.712074
# 7                2.603794                 5.527778                  5.45714
# 8                2.593961                 5.527778                 5.457402
# 9                0.937851                 8.490166                 8.450614
# 10               2.770881                 6.924415                 6.830379
# 11               2.760849                 6.924678                 6.830973
# 12               1.995575                 0.527778                 0.522162
# 13               2.905278                 8.559978                 8.438226
# 14               2.905278                 8.559978                 8.438226
#
#     IsCallable IndustrySubSectorDescription    Price PricingTradeDate
# 0        False                    Sovereign   99.859       2026-05-01
# 1        False                    Sovereign   99.352       2026-05-01
# 2        False                    Sovereign  115.793       2026-05-01
# 3        False                    Sovereign    97.27       2026-05-01
# 4        False                    Sovereign   98.719       2026-05-01
# 5        False                    Sovereign   93.371       2026-05-01
# 6        False                    Sovereign   47.406       2026-05-01
# 7        False                    Sovereign   86.746       2026-05-01
# 8        False                    Sovereign   86.792       2026-05-01
# 9        False                    Sovereign   93.161       2026-05-01
# 10       False                    Sovereign   96.495       2026-05-01
# 11       False                    Sovereign   96.561       2026-05-01
# 12       False                    Sovereign  100.108       2026-05-01
# 13       False                    Sovereign   94.604       2026-05-01
# 14       False                    Sovereign   94.604       2026-05-01

# %%
bond_ric_list_dk = corp_bond_search_dk.iloc[:,0].astype(str).tolist()+ gov_bond_search_dk.iloc[:,0].astype(str).tolist()

# %%
supplementary_dk = ld.get_data(
    universe=bond_ric_list_dk,
    fields=project_fields,
    parameters = {'SDate': '0CY', 'Curn': 'EUR'}
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /opt/anaconda3/lib/python3.12/site-packages/lseg/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
display(supplementary_dk.head(-5))
#supplementary_dk.to_csv("supplementary_dk.csv")
# Out:
#           Instrument              RIC Currency Issuer Rating  \
# 0    0#DK0030237029=  0#DK0030237029=      DKK
# 1    0#DK0030239314=  0#DK0030239314=      DKK
# 2    0#DK0030248067=  0#DK0030248067=      DKK
# 3    0#DK0030256169=  0#DK0030256169=      DKK
# 4      DK0002000421=    DK0002000421=      DKK            WR
# ..               ...              ...      ...           ...
# 510    DK0009924532=    DK0009924532=      DKK           AAA
# 511    DK0009924615=    DK0009924615=      DKK           AAA
# 512    DK0009924888=    DK0009924888=      DKK           AAA
# 513    DK0009924961=    DK0009924961=      DKK           AAA
# 514    DK0009925182=    DK0009925182=      DKK           AAA
#
#                            Rating Source Description       Date Fitchs Rating  \
# 0                                                           NaT
# 1                                                           NaT
# 2                                                           NaT
# 3                                                           NaT
# 4    Moody's Long-term Mortgage Covered Bonds Rating 2020-06-12
# ..                                               ...        ...           ...
# 510                      JCR Long-term Issuer Rating 2024-11-29           AAA
# 511                      JCR Long-term Issuer Rating 2024-11-29           AAA
# 512                      JCR Long-term Issuer Rating 2024-11-29           AAA
# 513                      JCR Long-term Issuer Rating 2024-11-29           AAA
# 514                      JCR Long-term Issuer Rating 2024-11-29           AAA
#
#     Fitchs Rating Date  SP Rating SP Rating Date  ... Modified Duration  \
# 0                  NaT       <NA>            NaT  ...              <NA>
# 1                  NaT       <NA>            NaT  ...              <NA>
# 2                  NaT       <NA>            NaT  ...              <NA>
# 3                  NaT       <NA>            NaT  ...              <NA>
# 4                  NaT       <NA>            NaT  ...          0.047898
# ..                 ...        ...            ...  ...               ...
# 510         2023-02-07       <NA>            NaT  ...          0.948285
# 511         2023-10-05       <NA>            NaT  ...          0.948406
# 512         2024-01-25       <NA>            NaT  ...          0.115152
# 513         2025-01-24       <NA>            NaT  ...          1.160212
# 514         2025-09-24       <NA>            NaT  ...          1.160199
#
#     Mac. Duration  Macaulay Duration Yield To Maturity  Yield to Maturity  \
# 0            <NA>               <NA>              <NA>               <NA>
# 1            <NA>               <NA>              <NA>               <NA>
# 2            <NA>               <NA>              <NA>               <NA>
# 3            <NA>               <NA>              <NA>               <NA>
# 4        0.155556               <NA>           2.54321
# ..            ...                ...               ...                ...
# 510      6.924415               <NA>          2.770881
# 511      6.924678               <NA>          2.760849
# 512      0.527778               <NA>          1.995575
# 513      8.559978               <NA>          2.905278
# 514      8.559978               <NA>          2.905278
#
#      Average Yield to Maturity  Yield to Maturity  \
# 0                         <NA>               <NA>
# 1                         <NA>               <NA>
# 2                         <NA>               <NA>
# 3                         <NA>               <NA>
# 4                                         0.97841
# ..                         ...                ...
# 510                                      2.761001
# 511                                      2.710734
# 512                                      2.010409
# 513                                      2.779442
# 514                                      2.855155
#
#                        Bond Grade  Par Value Face Issued Total
# 0                                   500000.0       450000000.0
# 1                                   500000.0       450000000.0
# 2                                   500000.0       350000000.0
# 3                                   500000.0       600000000.0
# 4                                       0.01      3926557000.0
# ..                            ...        ...               ...
# 510  Bond Grade: Investment Grade       0.01     78450000000.0
# 511  Bond Grade: Investment Grade       0.01     18165000000.0
# 512  Bond Grade: Investment Grade       0.01     32080000000.0
# 513  Bond Grade: Investment Grade       0.01     43580000000.0
# 514  Bond Grade: Investment Grade       0.01      9575000000.0
#
# [515 rows x 25 columns]

# %%
ld.close_session()

# %% [markdown]
# ## Data Transformation Stage 1

# %% [markdown]
# ### 2.1. Re-import all the available dataframes

# %% [markdown]
# #### 2.1.1. Discovery search dfs

# %%
from pathlib import Path

discovery_bond_files = sorted(Path(".").glob("*bond*.csv"))

bond_dfs = [pd.read_csv(file, index_col=0) for file in discovery_bond_files]

all_bonds_df = pd.concat(bond_dfs, ignore_index=True)

# %%
print([file.name for file in discovery_bond_files])
print(all_bonds_df.shape)
# Out:
# ['corp_bond_search_dk.csv', 'corp_bond_search_fi.csv', 'corp_bond_search_no.csv', 'corp_bond_search_se.csv', 'gov_bond_search_dk.csv', 'gov_bond_search_fi.csv', 'gov_bond_search_no.csv', 'gov_bond_search_se.csv']
# (1966, 19)

# %%
# If there is 4 unique values for the country, then we are good to go
if all_bonds_df['RCSCountryLeaf'].nunique()==4:
    print('All bonds from Finland, Sweden, Norway and Denmark were merged successfully')
else:
    print('ERROR: Check the imported files')
# Out:
# All bonds from Finland, Sweden, Norway and Denmark were merged successfully

# %%
#all_bonds_df.head()

# %% [markdown]
# #### 2.1.2. Supplementary dfs

# %%
supp_files = sorted(Path(".").glob("supplementary*"))

supp_dfs = [pd.read_csv(file, index_col=0) for file in supp_files]
all_supp_df = pd.concat(supp_dfs, ignore_index=True)

# %%
print([file.name for file in supp_files])
print(all_supp_df.shape)
# Out:
# ['supplementary_dk.csv', 'supplementary_fi.csv', 'supplementary_no.csv', 'supplementary_se.csv']
# (1932, 25)

# %%
#all_supp_df.head()

# %% [markdown]
# ### 2.2. Renaming columns of main source df

# %%
all_bonds_df = all_bonds_df.rename(columns={'DTSubjectName':'Entity',
                                    'DBSTicker':'Ticker',
                                    'RCSCurrencyLeaf':'Currency',
                                    'RCSCountryLeaf': 'Country',
                                    'DbTypeDescription': 'Category',
                                    'InstrumentTypeDescription':'Type',
                                    'RCSBondGradeLeaf':'Grade',
                                    'MaturityStandardYield': 'YTM',
                                    'MaturityCorpMacDuration': 'Macaulay Dur',
                                    'MaturityCorpModDuration': 'Mod Dur',
                                    'IndustrySubSectorDescription': 'Sector',
                                    'PricingTradeDate': 'Price Date'

                                   })

all_bonds_df = all_bonds_df.drop(columns=['Currency'])
#all_bonds_df.head(-5)

# %% [markdown]
# ### 2.3. Inspecting supplementary df
#
# As I mentioned in the introduction, the supplementary df is gathered to impute the missing values from the main references df obtained from discovery search. That is why we have "duplicate" fields which are named differently but basically refer to the same metrics. Below the duplicate columns are grouped together. The column with least NAs in the pair becomes a reference column to which we impute the values from the "duplicate" one.

# %% [markdown]
# ##### 2.3.1. Inspection of columns

# %%
all_supp_df.columns
# Out:
# Index(['Instrument', 'RIC', 'Currency', 'Issuer Rating',
#        'Rating Source Description', 'Date', 'Fitchs Rating',
#        'Fitchs Rating Date', 'SP Rating', 'SP Rating Date', 'Moodys Rating',
#        'Moodys Rating Date', 'Duration', 'Total Duration', 'Modified Duration',
#        'Modified Duration.1', 'Mac. Duration', 'Macaulay Duration',
#        'Yield To Maturity', 'Yield to Maturity', 'Average Yield to Maturity',
#        'Yield to Maturity.1', 'Bond Grade', 'Par Value', 'Face Issued Total'],
#       dtype='object')

# %%
all_supp_df = all_supp_df.rename(columns={"Date": "Issuer Rating Date"})

# %% [markdown]
# ##### 2.3.2. Identify the combinations of duplicate columns, analyze missing values in each
#
# I intend to analyze the missing values counts per each of the column to identify the one which has the least missings. Then this column will become a renference column to which we will impute the missing values with the rest helper columns.

# %%
duplicate_groups = {
    "duration": ["Duration", "Total Duration"],
    "modified_duration": ["Modified Duration", "Modified Duration.1"],
    "macaulay_duration": ["Mac. Duration", "Macaulay Duration"],
    "yield_to_maturity": ["Yield To Maturity", "Yield to Maturity", "Yield to Maturity.1"],
    "rating": ["Issuer Rating", "Fitchs Rating", "SP Rating", "Moodys Rating"],
    "rating_date": ["Issuer Rating Date", "Fitchs Rating Date", "SP Rating Date", "Moodys Rating Date"]

}

# %%
def missing_summary(df, groups):
    df=df.copy()

    # Convert empty strings / whitespace-only strings to missing values
    df = df.replace(r"^\s*$", pd.NA, regex=True)

     # Convert common text null markers to missing values
    df = df.replace(
        {
            "NULL": pd.NA,
            "null": pd.NA,
            "NaN": pd.NA,
            "nan": pd.NA,
            "N/A": pd.NA,
            "<NA>":pd.NA,
            "NaT": pd.NA,
            "n/a": pd.NA,

        }
    )
    summary_rows = []

    for group_name, cols in groups.items():
        existing_cols = [col for col in cols]

        for col in existing_cols:
            na_count = df[col].isna().sum()
            non_na_count = df[col].notna().sum()
            na_share = na_count/len(df)

            summary_rows.append({
                "group": group_name,
                "column": col,
                "na_count": na_count,
                "non_na_count": non_na_count,
                "na_share": na_share,

            })

    summary_df = pd.DataFrame(summary_rows).sort_values(by=["group", "na_count", "column"]).reset_index(drop=True)

    return summary_df

na_summary_df = summarize_missing_by_group(all_supp_df, duplicate_groups)
na_summary_df
# Out:
#                 group               column  na_count  non_na_count  na_share
# 0            duration             Duration       411          1521  0.212733
# 1            duration       Total Duration      1932             0  1.000000
# 2   macaulay_duration        Mac. Duration       633          1299  0.327640
# 3   macaulay_duration    Macaulay Duration      1912            20  0.989648
# 4   modified_duration    Modified Duration       411          1521  0.212733
# 5   modified_duration  Modified Duration.1      1118           814  0.578675
# 6              rating        Issuer Rating       738          1194  0.381988
# 7              rating        Moodys Rating      1569           363  0.812112
# 8              rating        Fitchs Rating      1759           173  0.910455
# 9              rating            SP Rating      1932             0  1.000000
# 10        rating_date   Moodys Rating Date         4          1928  0.002070
# 11        rating_date   Issuer Rating Date       738          1194  0.381988
# 12        rating_date   Fitchs Rating Date      1759           173  0.910455
# 13        rating_date       SP Rating Date      1932             0  1.000000
# 14  yield_to_maturity  Yield to Maturity.1       411          1521  0.212733
# 15  yield_to_maturity    Yield To Maturity       632          1300  0.327122
# 16  yield_to_maturity    Yield to Maturity      1925             7  0.996377

# %% [markdown]
# ##### 2.3.3. Missing value imputation
#
# Below, a dictionary called **mapped_columns** is created to define how overlapping supplementary fields should be combined into final output columns using waterfall priority.
#
# In this dictionary:
# - the key represents the desired final output column in the DataFrame
# - the value is a tuple containing the ordered components used to construct that output column
#
# The logic is based on a reference-column-first waterfall:
# - the first item in the tuple is always treated as the reference column
# - missing values in this reference column are then filled using the remaining items in the tuple from left to right
#
# The function **impute_cols()** takes two arguments:
#
# 1. the source DataFrame
# 2. the mapped_columns dictionary
#
# For each output column, the function applies the following rules:
# - the reference column must exist in the source DataFrame
# - each following item in the tuple is interpreted as:
#     - DataFrame column, if a column with that exact name exists in the DataFrame
#     - otherwise, a literal string value, which is passed directly into fillna()
#
# This makes it possible to handle both ordinary column-to-column imputations and cases where a hardcoded fallback label is needed, such as for rating sources.
#
# A very important requirement is that all columns logically related to a given output column must be included in the corresponding tuple inside mapped_columns. Otherwise, the function will not work as intended.

# %%
mapped_columns = {
    "Duration": ("Duration", "Total Duration"),
    "Macaulay Duration": ("Mac. Duration", "Macaulay Duration"),
    "Modified Duration": ("Modified Duration", "Modified Duration.1"),
    "Rating": ("Issuer Rating", "Moodys Rating", "Fitchs Rating", "SP Rating"),
    "Rating Date": ("Issuer Rating Date", "Moodys Rating Date", "Fitchs Rating Date", "SP Rating Date"),
    "Rating Source": ("Rating Source Description", "Moodys", "Fitchs", "SP"),
    "YTM": ("Yield to Maturity.1", "Yield To Maturity", "Yield to Maturity", "Average Yield to Maturity"),
}

# %%
def impute_cols(df, mapped_columns):
    df = df.copy()

    # standardize empty / null-like strings first
    df = df.replace(r"^\s*$", pd.NA, regex=True)
    
    df = df.replace(
        {
            "NULL": pd.NA,
            "null": pd.NA,
            "NaN": pd.NA,
            "nan": pd.NA,
            "N/A": pd.NA,
            "<NA>": pd.NA,
            "NaT": pd.NA,
            "n/a": pd.NA,
        }

    )

    used_source_cols = []

    for output_col, components in mapped_columns.items():
        if not components:
            continue

        reference_col = components[0]

        if reference_col not in df.columns:
            raise KeyError(f'Reference column "{reference_col}" (first column in the tuple) does not exist')

        # Start from the reference column
        df[output_col] = df[reference_col]
        used_source_cols.append(reference_col)

        # Fill from the remaining components
        for component in components[1:]:
            if component in df.columns:
                df[output_col] = df[output_col].fillna(df[component])
                used_source_cols.append(component)

            else:
                # Treat as literal string value
                df[output_col] = df[output_col].fillna(component)

    used_source_cols = list(dict.fromkeys(used_source_cols))

    # Drop source columns used to build outputs, but keep final output columns
    cols_to_drop = df.columns.intersection(used_source_cols).difference(mapped_columns.keys())
    df = df.drop(columns=cols_to_drop, errors="ignore")

    return df

# %%
all_supp_clean_df = impute_cols(all_supp_df, mapped_columns)

# %%
all_supp_clean_df.isna().sum()
# Out:
# Instrument              1
# RIC                     1
# Currency                4
# Duration              411
# Modified Duration     361
# Macaulay Duration     633
# Bond Grade           1748
# Par Value               4
# Face Issued Total      58
# Rating                691
# Rating Date             4
# Rating Source           0
# YTM                   350
# dtype: int64

# %%
na_summary_df.iloc[[0, 2, 4, 6, 14], [1,2]]
# Out:
#                  column  na_count
# 0              Duration       411
# 2         Mac. Duration       633
# 4     Modified Duration       411
# 6         Issuer Rating       738
# 14  Yield to Maturity.1       411

# %% [markdown]
# Using the imputation, we have been able to reduce the number of NAs for the follwing final columns:
# - Modified Duration: 50
# - Rating: 47
# - YTM: 61

# %% [markdown]
# ### 2.4. Merge the data frames

# %%
bond_df = pd.merge(all_bonds_df, all_supp_clean_df, left_on='RIC', right_on='RIC')

bond_df = bond_df.drop(columns=['Instrument'])
display(bond_df.head())
bond_df.columns
# Out:
#                RIC                                Entity  Ticker  CouponRate  \
# 0  0#DK0030237029=                          Sjf Bank A/S     SJF      1.8300
# 1  0#DK0030239314=                          Sjf Bank A/S     SJF      1.8825
# 2  0#DK0030248067=                          Sjf Bank A/S     SJF      1.6750
# 3  0#DK0030256169=                    Fjordbank Mors A/S   FJORB      1.6550
# 4    DK0002000421=  Nordea Kredit Realkreditaktieselskab  NDARFI      6.0000
#
#   MaturityDate   IssueDate          ISIN  Country   Category  \
# 0   2013-03-12  2010-03-12  DK0030237029  Denmark  Corporate
# 1   2013-04-23  2010-04-23  DK0030239314  Denmark  Corporate
# 2   2013-06-28  2010-06-28  DK0030248067  Denmark  Corporate
# 3   2013-07-22  2010-07-22  DK0030256169  Denmark  Corporate
# 4   2026-07-01  1993-10-18  DK0002000421  Denmark  Corporate
#
#                                                 Type  ...  Duration  \
# 0                                               Bond  ...       NaN
# 1                                               Bond  ...       NaN
# 2                                               Bond  ...       NaN
# 3                                               Bond  ...       NaN
# 4  Realkreditobligation (Covered bond (Denmark pr...  ...    0.1583
#
#    Modified Duration  Macaulay Duration  Bond Grade  Par Value  \
# 0                NaN                NaN         NaN  500000.00
# 1                NaN                NaN         NaN  500000.00
# 2                NaN                NaN         NaN  500000.00
# 3                NaN                NaN         NaN  500000.00
# 4             0.1581           0.155556         NaN       0.01
#
#    Face Issued Total Rating Rating Date  \
# 0       4.500000e+08    NaN  2010-03-12
# 1       4.500000e+08    NaN  2010-04-23
# 2       3.500000e+08    NaN  2010-06-28
# 3       6.000000e+08    NaN  2010-07-22
# 4       3.926557e+09     WR  2020-06-12
#
#                                      Rating Source    YTM_y
# 0                                           Moodys      NaN
# 1                                           Moodys      NaN
# 2                                           Moodys      NaN
# 3                                           Moodys      NaN
# 4  Moody's Long-term Mortgage Covered Bonds Rating  0.97841
#
# [5 rows x 29 columns]
# Index(['RIC', 'Entity', 'Ticker', 'CouponRate', 'MaturityDate', 'IssueDate',
#        'ISIN', 'Country', 'Category', 'Type', 'YTM_x', 'Macaulay Dur',
#        'Mod Dur', 'IsCallable', 'Sector', 'Price', 'Price Date', 'Grade',
#        'Currency', 'Duration', 'Modified Duration', 'Macaulay Duration',
#        'Bond Grade', 'Par Value', 'Face Issued Total', 'Rating', 'Rating Date',
#        'Rating Source', 'YTM_y'],
#       dtype='object')

# %% [markdown]
# ### 2.5. Final Data Cleansing

# %% [markdown]
# #### 2.5.1. Replacing empty values with NAs

# %%
# Safety check with LSEG returning "not NA" but empty entries sometimes
# counting the instances where th value is just empty with the help of regex
bond_df = bond_df.replace(r"^\s*$", pd.NA, regex=True)

# %%
bond_df.isna().sum()
# Out:
# RIC                    38
# Entity                  0
# Ticker                  1
# CouponRate             12
# MaturityDate           58
# IssueDate               0
# ISIN                    0
# Country                 0
# Category                0
# Type                    0
# YTM_x                 648
# Macaulay Dur          649
# Mod Dur               649
# IsCallable              0
# Sector                  0
# Price                 646
# Price Date            646
# Grade                1782
# Currency               41
# Duration              448
# Modified Duration     398
# Macaulay Duration     670
# Bond Grade           1785
# Par Value              41
# Face Issued Total      95
# Rating                728
# Rating Date            41
# Rating Source           0
# YTM_y                 387
# dtype: int64

# %% [markdown]
# ##### 2.5.2. Drop duplicate RICs

# %%
bond_df = bond_df.drop_duplicates(subset=['RIC'])
print(bond_df.shape)
# Out:
# (1929, 29)

# %% [markdown]
# #### 2.5.3. Inpute missing values from the duplicate columns (reference step 2.3.3)

# %%
mapped_columns = {
    "Macaulay Duration": ("Macaulay Dur", "Macaulay Duration"),
    "Modified Duration": ("Mod Dur", "Modified Duration"),
    "Grade": ("Grade", "Bond Grade"),
    "YTM": ("YTM_x", "YTM_y")
}

# %%
bond_clean_df = impute_cols(bond_df, mapped_columns)

# %% [markdown]
# #### 2.5.4. Convert date columns to date and subset the maturity dates before today

# %%
def convert_date_columns(df):

    df = df.copy()
    date_cols = [col for col in df.columns if "date" in col.lower()]
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], errors="coerce")

    return df
bond_clean_df = convert_date_columns(bond_clean_df)

# %%
# Keep only bonds which mature after today

bond_clean_df = bond_clean_df.loc[bond_clean_df["MaturityDate"] >= pd.Timestamp.today().normalize()]
bond_clean_df.shape
# Out:
# (1847, 25)

# %%
bond_clean_df.to_excel("bond_clean.xlsx")

# %% [markdown]
# # Data Transformation stage 2

# %% [markdown]
# ## 3.1. Filtering the rows with non-empty target variable - Rating

# %%
bond_ml = bond_clean_df[bond_clean_df["Rating"].notna()].reset_index(drop=True)

bond_ml.shape
# Out:
# (1224, 25)

# %% [markdown]
# ## 3.2. Select the sub-set of features and drop missing entries

# %%
bond_ml.isna().sum()
# Out:
# RIC                     0
# Entity                  0
# Ticker                  1
# CouponRate             10
# MaturityDate            0
# IssueDate               0
# ISIN                    0
# Country                 0
# Category                0
# Type                    0
# IsCallable              0
# Sector                  0
# Price                 325
# Price Date            325
# Grade                1049
# Currency                0
# Duration              344
# Modified Duration     327
# Macaulay Duration     327
# Par Value               0
# Face Issued Total      53
# Rating                  0
# Rating Date             0
# Rating Source           0
# YTM                   281
# dtype: int64

# %%
cols_to_keep = ["RIC","Country", "Currency", "Sector", "Rating", "CouponRate", "YTM", "Modified Duration", "Face Issued Total", 
                "MaturityDate", "IssueDate", "IsCallable"]

bond_ml = bond_ml[cols_to_keep]

bond_ml.head()
# Out:
#              RIC  Country Currency            Sector Rating  CouponRate  \
# 0  DK0002000421=  Denmark      DKK  Mortgage Banking     WR         6.0
# 1  DK0002004092=  Denmark      DKK  Mortgage Banking     WR         6.0
# 2  DK0002004258=  Denmark      DKK  Mortgage Banking     WR         7.0
# 3  DK0002004415=  Denmark      DKK  Mortgage Banking     WR         8.0
# 4  DK0002004845=  Denmark      DKK  Mortgage Banking     WR         5.0
#
#          YTM  Modified Duration  Face Issued Total MaturityDate  IssueDate  \
# 0   2.543210           0.154932       3.926557e+09   2026-07-01 1993-10-18
# 1   4.076302           1.587514       5.184584e+10   2029-07-01 1996-09-01
# 2   3.938024           1.589776       2.918708e+10   2029-07-01 1996-09-01
# 3 -42.069554                NaN       1.003387e+10   2026-10-01 1996-09-01
# 4   3.672154           1.594135       8.745365e+09   2029-07-01 1998-06-01
#
#    IsCallable
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
bond_ml.dropna(subset=['CouponRate', 'YTM', 'Modified Duration', 'Face Issued Total'], how="any", inplace=True)
print(bond_ml.shape)
# Out:
# (861, 12)

# %% [markdown]
# ## 3.3. Feature cleaning

# %%
bond_ml['Rating'].value_counts()
# Out:
# Rating
# WR            265
# AAA           197
# A-             56
# Baa2           44
# A3             41
# AA             35
# Aaa            34
# BBB-           26
# baa1           21
# Aa3(cr)        17
# a3             17
# A1(cr)         12
# NR             12
# P-1            10
# Baa3           10
# A1              8
# Baa1            6
# baa2            6
# A2(cr)          6
# AA (low)        6
# Ba2             5
# aa3             5
# WD              3
# A+              3
# A2              2
# A               2
# BBB+            2
# AA-             2
# CCC+            2
# a2              1
# N-2             1
# BBB (high)      1
# (P)A3           1
# Aa2             1
# Caa2            1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3.1. Rating standardization

# %%
prime = {"P-1", "N-2"}

aaa = {"AAA", "Aaa"}

aa_a = {"AA", "AA-", "AA (low)",
        "Aa2", "Aa3(cr)", "aa3",
        "A+", "A", "A-",
        "A1", "A2", "A3",
        "A1(cr)", "A2(cr)",
        "a2", "a3",
        "(P)A3"}

bbb = {"BBB+", "BBB-", "BBB (high)",
        "Baa1", "Baa2", "Baa3",
        "baa1", "baa2"}

other = {"Ba2", "CCC+", "Caa2",
        "WR", "NR", "WD"}

# %%
def standardize_rating(rating):
    r = str(rating).strip()

    if r in prime:
        return "Prime"

    elif r in aaa:
        return "AAA"

    elif r in aa_a:
        return "AA-A"
    elif r in bbb:
        return "BBB"

    elif r in other:

        return "Other"

    else:
        return "Unmapped"

# %%
bond_ml["rating"] = bond_ml["Rating"].apply(standardize_rating)

bond_ml['rating'].value_counts()
# Out:
# rating
# Other    288
# AAA      231
# AA-A     215
# BBB      116
# Prime     11
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3.2. Sector standardization

# %%
bond_ml['Sector'].value_counts()
# Out:
# Sector
# Mortgage Banking                310
# Banking                         235
# Sovereign                        98
# Home Builders                    90
# Financial - Other                80
# Retail Stores - Other            11
# Service - Other                   9
# Electronics                       4
# Machinery                         4
# Industrials - Other               4
# Conglomerate/Diversified Mfg      3
# Containers                        2
# Airline                           2
# Metals/Mining                     2
# Life Insurance                    1
# Chemicals                         1
# Transportation - Other            1
# Railroads                         1
# Telecommunications                1
# Oil and Gas                       1
# Utility - Other                   1
# Name: count, dtype: int64

# %%
sector_mapping = {

    # Financials 
    "Mortgage Banking": "Financials",
    "Banking": "Financials",
    "Financial - Other": "Financials",
    "Life Insurance": "Financials",


    # Sovereigns 
    "Sovereign": "Sovereign/Public",

    # Real Estate
    "Home Builders": "Real Estate/Housing",


    # Industrials
    "Machinery": "Industrials/Transport",
    "Industrials - Other": "Industrials/Transport",
    "Conglomerate/Diversified Mfg": "Industrials/Transport",
    "Containers": "Industrials/Transport",
    "Airline": "Industrials/Transport",
    "Transportation - Other": "Industrials/Transport",
    "Railroads": "Industrials/Transport",

    # Consumer
    "Retail Stores - Other": "Consumer/Services",
    "Service - Other": "Consumer/Services",

    # Energy and utils
    "Metals/Mining": "Energy/Materials/Utilities",
    "Chemicals": "Energy/Materials/Utilities",
    "Oil and Gas": "Energy/Materials/Utilities",
    "Utility - Other": "Energy/Materials/Utilities",

    # Tech
    "Electronics": "Technology/Telecom",
    "Telecommunications": "Technology/Telecom",

}

# %%
bond_ml["sector_std"] = bond_ml["Sector"].map(sector_mapping)
bond_ml = bond_ml.drop(columns=["Rating", "Sector"])

# %% [markdown]
# ### 3.3.3. Maturity length calculation

# %%
bond_ml['Maturity'] = ((bond_ml['MaturityDate'] - bond_ml['IssueDate']).dt.days / 365).round(2)

bond_ml.drop(columns=['IssueDate', 'MaturityDate', 'Currency', 'RIC'], inplace=True)

# %%
display(bond_ml.head())
print()
print(bond_ml.shape)
#bond_ml.to_excel("bond_ml.xlsx")
# Out:
#    Country  CouponRate       YTM  Modified Duration  Face Issued Total  \
# 0  Denmark         6.0  2.543210           0.154932       3.926557e+09
# 1  Denmark         6.0  4.076302           1.587514       5.184584e+10
# 2  Denmark         7.0  3.938024           1.589776       2.918708e+10
# 4  Denmark         5.0  3.672154           1.594135       8.745365e+09
# 5  Denmark         5.0  3.985255           3.079560       4.962614e+09
#
#    IsCallable rating  sector_std  Maturity
# 0        True  Other  Financials     32.72
# 1        True  Other  Financials     32.85
# 2        True  Other  Financials     32.85
# 4        True  Other  Financials     31.10
# 5        True  Other  Financials     33.28
# (861, 9)

# %% [markdown]
# # Visuals

# %% [markdown]
# ## 4.1. Average metrics per rating

# %%
# Colums to be plotted
cols = ['CouponRate', 'YTM', 'Modified Duration', 'Face Issued Total', 'Maturity']

#calculating average
average = bond_ml.groupby(['rating', 'Country']).mean(cols).round(2).reset_index()

#Ordering the rating, not according to alphabetical order
rating_order = ["Prime", "AAA", "AA-A", "BBB", "Other"]
average["rating"] = pd.Categorical(average["rating"],categories=rating_order,ordered=True)


display(average)
# Out:
#    rating  Country  CouponRate   YTM  Modified Duration  Face Issued Total  \
# 0    AA-A  Denmark        2.76  3.40               6.32       6.439365e+08
# 1    AA-A  Finland        1.42  2.54               6.06       4.540614e+09
# 2    AA-A   Norway        3.22  5.73               2.17       1.476458e+09
# 3    AA-A   Sweden        3.03  1.58               0.48       1.082439e+09
# 4     AAA  Denmark        2.00  3.18               5.88       1.305631e+10
# 5     AAA  Finland        1.45  2.90               2.28       1.050000e+09
# 6     AAA   Norway        2.56  4.61               3.59       2.188422e+10
# 7     AAA   Sweden        1.57  2.27               4.01       3.388299e+10
# 8     BBB  Finland        3.14  3.76               3.39       2.555556e+08
# 9     BBB   Norway        3.41  5.32               2.38       8.147500e+08
# 10    BBB   Sweden        3.13  2.98               1.43       1.286761e+09
# 11  Other  Denmark        3.14  3.28               4.94       7.772867e+09
# 12  Other  Finland        4.50  4.74               3.40       4.000000e+08
# 13  Other   Norway        3.61  5.88               1.51       1.225679e+09
# 14  Other   Sweden        3.56  5.07               0.43       9.561111e+08
# 15  Prime   Norway        3.69  5.05               0.75       9.214286e+08
# 16  Prime   Sweden        1.44  2.80               2.21       1.125000e+09
#
#     IsCallable  Maturity
# 0         0.79     27.19
# 1         0.02     11.19
# 2         0.12     10.56
# 3         0.09      4.97
# 4         0.51     18.19
# 5         0.00      7.50
# 6         0.00      9.53
# 7         0.00     10.64
# 8         0.78      7.19
# 9         0.03      9.79
# 10        0.07      6.67
# 11        0.74     22.80
# 12        1.00      5.00
# 13        0.30      8.70
# 14        0.14      4.53
# 15        0.14      8.08
# 16        0.00      6.76

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

fig, axes = plt.subplots(2,3, figsize = (15,8))

axes = axes.flatten()

for ax, col in zip(axes, cols):
    sns.barplot(data=average, x='rating', y=average[col], hue=average['Country'], ax=ax)
    ax.set_title(f"Average {col} per rating and country")

axes[-1].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Some observations:
#
# ##### Coupon
#
# There is an interesting tendency shown in case of Finnish and Swedish bonds, the lower the rating is, the higher average coupon rate becomes. This does make sense as the riskier bonds should compensate the investors with higher coupon payments. Trend is not that drastically visible in case of Norwegian and Danish bonds, but still such concklusion is still applicable, with exception of Prime bonds for Norway
#
# ##### YTM
#
# Again, Norway seems to have different pattern than e.g. Finland or Sweden - it has the highest YTM values across all rating buckets. If we check Sweden or Finland, the YTM is highest in case of BBB and Other categories of the bonds, which as well makes sense as in the previous point. Logically, AAA rated bonds have lower YTM. YTM appears to move in a direction that is broadly consistent with risk differentiation, suggesting a solid reason to include the estimator to the classification model.
#
# At the same time, the country effect is strong. That means the model may learn both differences in credit quality and differences in national bond market environments.
#
# ##### Modified Duration
#
# The pattern is more mixed than in comparison to CouponRate or YTM. Denmark has the highest scores of modified duration across all rating buckets. It means that Danish bond prices are most sensitive to the interest rate changes, which might also determine the rating classification. AA-A rating has the highest sensitivity, Finland is almost at par with Sweden. One interesting feature is that duration seems especially high in some stronger rating categories. That is not a surprise as highly rated bonds may simply be issued with longer maturities or lower coupons, which mechanically increases duration.
#
# ##### Maturity
#
# Indeed, higher rating bonds (AAA and AA-A) have a slightly higher maturity time than the lower rating bonds. This kind of supports the statement that higher rating bonds have the higher duration which coincides with the higher maturity time. Denmark again shows the highest scores acorss the board, so geographical factor indeed will play a role in the model.

# %% [markdown]
# # Feature normalization for classification models

# %% [markdown]
# ### 4.1. Remapping the IsCallable to binary outcome

# %%
bond_ml['IsCallable'] = bond_ml['IsCallable'].astype(int)

# %% [markdown]
# ### 4.2. Label Encoder for the categorical variables

# %%
from sklearn.preprocessing import LabelEncoder

le_rating = LabelEncoder()
bond_ml['rating'] = le_rating.fit_transform(bond_ml['rating'])

le_country = LabelEncoder()
bond_ml['Country'] = le_country.fit_transform(bond_ml['Country'])

le_sector_std = LabelEncoder()
bond_ml['sector_std'] = le_sector_std.fit_transform(bond_ml['sector_std'])

# %% [markdown]
# ### 4.3. Standard scaler to numerical variables

# %%
from sklearn.preprocessing import StandardScaler

standardized_cols = ['YTM', 'Modified Duration', 'CouponRate', 'Face Issued Total', 'Maturity']
scaler_standard = StandardScaler()

bond_ml[standardized_cols] = scaler_standard.fit_transform(bond_ml[standardized_cols])

# %%
bond_ml.head()
# Out:
#    Country  CouponRate       YTM  Modified Duration  Face Issued Total  \
# 0        0    1.931013 -0.240926          -0.896495          -0.216931
# 1        0    1.931013  0.140733          -0.556317           2.792528
# 2        0    2.525579  0.106309          -0.555780           1.369497
# 4        0    1.336447  0.040122          -0.554744           0.085703
# 5        0    1.336447  0.118067          -0.202018          -0.151864
#
#    IsCallable  rating  sector_std  Maturity
# 0           1       3           2  1.524182
# 1           1       3           2  1.535463
# 2           1       3           2  1.535463
# 4           1       3           2  1.383597
# 5           1       3           2  1.572779

# %% [markdown]
# # Statistical learning

# %% [markdown]
# ## 5.1. Train-validation-test splits

# %%
from sklearn.model_selection import train_test_split

rand_state = 100

y = bond_ml['rating']
X = bond_ml.drop(columns=['rating'])

#60-20-20: Train-validation-test set 

X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, random_state=rand_state)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.2, random_state=rand_state)

print("Train set size:", X_train.shape[0])
print()
print("Validation set size:", X_val.shape[0])
print()
print("Test set size:", X_test.shape[0])
# Out:
# Train set size: 550
#
# Validation set size: 138
#
# Test set size: 173

# %%
print("Target label balance:")
pd.crosstab(bond_ml['rating'], bond_ml['rating'], normalize='all').reset_index(drop=True)
# Out:
# Target label balance:
# rating        0         1         2         3         4
# 0       0.24971  0.000000  0.000000  0.000000  0.000000
# 1       0.00000  0.268293  0.000000  0.000000  0.000000
# 2       0.00000  0.000000  0.134727  0.000000  0.000000
# 3       0.00000  0.000000  0.000000  0.334495  0.000000
# 4       0.00000  0.000000  0.000000  0.000000  0.012776

# %% [markdown]
# ## 5.2. Motivation for model selection
#
# I will proceed with the following models to classify the rating of the bond:
#
# 1. **Logistics Regression** - baseline model. Regressions in general are used as baseline models. It is simple and interpretable.
# 2. **Random forests** - tree based ensemble methods are in general also easy to interpet. Random forests improves the basic classification tree by applying bootstrap with replacement which is super suitable in my case as I had to strip many observations from the dataset because LSEG was not in good mood. Moreover, it randomly selects the subset of the features, and in current setup have some variables which might not play a significant role like Maturity or Amount Issued.

# %% [markdown]
# ## 5.3. Setting up hyperparameters for the chosen models

# %%
rf_param_grid = {
    "n_estimators": [100, 200, 500, 800], #number of fitted trees
    "min_samples_leaf": [1, 2, 5, 10, 20], #minimum number of observations per each leaf
    "max_leaf_nodes": [None, 10, 20, 50, 100], #maximum number of leaves per each tree
    "max_depth": [None, 5, 10, 20] #number of main splits allowed per tree
}

# %%
logit_param_grid = {
    "penalty": ['l1', 'l2'],
    "C": [0.001, 0.01, 0.1, 1, 10, 100], #regularization strength, complexity parameter
    "solver": ["liblinear"]
}

# %% [markdown]
# ## 5.4. Training and validating models using cross-validation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report

# %%
grid_rf = GridSearchCV(RandomForestClassifier(random_state=rand_state), rf_param_grid, cv=5, scoring="f1_weighted", n_jobs=-1)
grid_rf.fit(X_train, y_train)

print("Best RF parameters are:", grid_rf.best_params_)
print("Best RF Weighted F1 (CV):",f"{grid_rf.best_score_:.4f}")

y_pred_rf_tuned = grid_rf.best_estimator_.predict(X_val)
# Out:
# Best RF parameters are: {'max_depth': None, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'n_estimators': 200}
# Best RF Weighted F1 (CV): 0.6700

# %%
rf_val_f1_weighted = f1_score(y_val, y_pred_rf_tuned, average="weighted")
print("RF Weighted F1 (Validation):", f"{rf_val_f1_weighted:.4f}")
# Out:
# RF Weighted F1 (Validation): 0.6588

# %%
print("\nClassification report (validation):")
print(classification_report(y_val, y_pred_rf_tuned, target_names=le_rating.classes_))
print("\nConfusion matrix (validation):")
cm = confusion_matrix(y_val, y_pred_rf_tuned)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le_rating.classes_)

disp.plot()
# Out:
# Classification report (validation):
#               precision    recall  f1-score   support
#
#         AA-A       0.63      0.81      0.71        27
#          AAA       0.73      0.54      0.62        41
#          BBB       0.58      0.78      0.67        18
#        Other       0.69      0.68      0.69        50
#        Prime       0.00      0.00      0.00         2
#
#     accuracy                           0.67       138
#    macro avg       0.53      0.56      0.54       138
# weighted avg       0.67      0.67      0.66       138
#
#
# Confusion matrix (validation):
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531:UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531:UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531:UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
from sklearn.linear_model import LogisticRegression

grid_logit = GridSearchCV(LogisticRegression(max_iter=500, class_weight="balanced", random_state=rand_state), logit_param_grid, 
                                                cv=5, scoring="f1_weighted",n_jobs=-1)

grid_logit.fit(X_train, y_train)

print("Best logistics regression parameters are:", grid_logit.best_params_)
print("Best LR Weighted F1 (CV):", f"{grid_logit.best_score_:.4f}")

y_pred_logit_tuned = grid_logit.best_estimator_.predict(X_val)
# Out:
# Best logistics regression parameters are: {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# Best LR Weighted F1 (CV): 0.4881

# %%
logit_val_f1_weighted = f1_score(y_val, y_pred_logit_tuned, average="weighted")
print("Logistics Reg Weighted F1 (Validation):", f"{logit_val_f1_weighted:.4f}")
# Out:
# Logistics Reg Weighted F1 (Validation): 0.5449

# %%
print("\nClassification report (validation):")
print(classification_report(y_val, y_pred_logit_tuned, target_names=le_rating.classes_))

cm = confusion_matrix(y_val, y_pred_logit_tuned)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le_rating.classes_)

disp.plot()
# Out:
# Classification report (validation):
#               precision    recall  f1-score   support
#
#         AA-A       0.71      0.37      0.49        27
#          AAA       0.59      0.63      0.61        41
#          BBB       0.48      0.67      0.56        18
#        Other       0.60      0.48      0.53        50
#        Prime       0.07      0.50      0.12         2
#
#     accuracy                           0.53       138
#    macro avg       0.49      0.53      0.46       138
# weighted avg       0.60      0.53      0.54       138
